# %% [markdown]
# # Домашнее задание по Excel
#
# Задания не имеют чёткой градации по сложности!
#
# Попробуйте построить графики везде где это можно! (Гистограмму, к тому как от сезона к сезону(или другой величене) меняется какая нибудь величена)
#
# __Если у вас не получаеться решить задачу, попробуйте решить другую задачу__!
#
# __Во всех задачах чем проще реализация и решение тем лучше!__
#
#
# Или попробывать решить через Python(для отработки навыка работы с данными через инструменты Python + Anaconda)!

# %% [markdown]
# ## Задание 1
#
#
#
# В этой задаче у нас есть файл, который называется `Задание_1_Excel.xlsx`, в нём хранится три таблицы.
# В первой таблице:`Города`, хранятся список городов, во второй таблице: `Адреса`, хранятся необходимые нам адреса. Необходимо объединить соединить две таблцы, чтобы получилось как в таблице: `Вывод`.
#
# Эту задачу реализуйте двумя способами с помощью Excel.
#
#
#  __*Усложнение__: Попробуйте записать(или написать) макрос, для того, чтобы автоматически можно было объединять таблицы

# %% [markdown]
# ## Задание 2
#
# На основании данных из `Задание_2-4_Excel.xlsx` сделать сводную таблицу по Брендам 1, 2 и 3 следующего вида:
#
#
# |  | Январь | Февраль | ... | Декабрь | Средние значение продаж за год
# | --- | --- | --- | --- | --- | --- |
# | 2021 | продажи | продажи | ... | продажи | Среднее значение за 2021 год |
# | 2022 | продажи | продажи | ... | продажи | Среднее значение за 2022 год |
# | 2023 | продажи | продажи | ... | продажи | Среднее значение за 2023 год |
#
# Для каждого бренда отдельную таблицу, вместо слова: `продажа`, расчитать на сколько продали, а вместо `Среднее значение за 202? год`, срденее значение за год.

# %% [markdown]
# ## Задание 3
#
# На основании данных из `Задание_2-4_Excel.xlsx` сводной таблицы рассчитать коэффициенты сезонности (учитывать 2021 и 2022 год)
#
# 1. $ Коэффицент\ сезонности\ за\ месяц = Количество\ продаж\ за\ месяц / Средняя\ величена\ продаж\ за\ год $
# 2. $ Коэффицент\ сезонности\ за\ год = Сумма\ коэффицентов\ сезонности\ за\ все\ месяцы / 12 $
#
# |  | Январь | Февраль | ... | Декабрь | Коэффицент сезонности за год |
# | --- | --- | --- | --- | --- | --- |
# | 2021 | Коэффицент | Коэффицент | ... | Коэффицент | Коэффицент за 2021 год |
# | 2022 | Коэффицент | Коэффицент | ... | Коэффицент | Коэффицент за 2022 год |
# | 2023 | Коэффицент | Коэффицент | ... | Коэффицент | Коэффицент за 2023 год |

# %% [markdown]
# ## Задание 4
#
# Объедините три таблицы в одну и заполнить таблицу, используя по возможности формулы. Значения - продажи из таблицы `Задание_2-4_Excel.xlsx`.
#
# | Бренд | Год | Январь | Февраль | ... | Декабрь |
# | --- | --- | --- | --- | --- | --- |
# | Бренд 1 | 2021 | продажи | продажи | ... | продажи |
# | Бренд 1 | 2022 | продажи | продажи | ... | продажи |
# | Бренд 1 | 2023 | продажи | продажи | ... | продажи |
# | Бренд 2 | 2021 | продажи | продажи | ... | продажи |
# | Бренд 2 | 2022 | продажи | продажи | ... | продажи |
# | Бренд 2 | 2023 | продажи | продажи | ... | продажи |
# | ...| ... | ... | ... | ... | ... |
#
# Но не во всех месяцах есть реализация и эти значение необходимо предсказать!
# Чтобы предсказать эти значения, воспользуйтесь функцией `ПРЕДСКАЗ()` из Excel, которая пытается построить линией апроксимировать(приблизить) значение продаж, и умножете на коэффицент сезонности (проще говороя: `ПРЕДСКАЗ(за какой месяц) * Коэффицент сезонности за прошлый месяц`)

# %% [markdown]
# ## Задание 5
#
# Транспонируйте полученную матрицу из Задания 4.
#
# Если не получилось Задание 4, то транспонируйте матрицу из Задания 2 - 3.

# %% [markdown]
# ## Задание 6
#
# Необходимо построить удобный график в использовании для рядового пользователя по динамике в разрезе периодов по следующим показателям:
# 1) Цены (в руб за кг продукции без ндс и бонуса);
# 2) Объемы (в тоннах);
# 3) Сумма приходов (в тыс. руб без НДС и бонуса).
#
# Все данные хранятся в таблице: `Задание_6_Excel.xlsx`

# %% [markdown]
# ## Задание 7
#
# Разбить по пробелу колонку на несколько колонок
#
# Таблица:
#
# | |
# | --- |
# | 0018. ГО         ф-ла              Самарский |
# | 1059.          роо           Ставропольский	|
# | 2010.            ДО         Центр автокредитования |
# | 0002.        ГО ф-ла        Екатеринбургский |
# | 2007.        роо       Кемеровский	|
# | 0051.          ГО ф-ла           Воронежский	|
#
# Разбейте на 3 колонки!

# %% [markdown]
# ## Задание 8
#
# Склей через пробел в одну колонку три поля:
# | | | |
# | --- | --- | --- |
# |Лебедева | Юлия | Андреевна |
# | Порхунова | Татьяна | Сергеевна |

# %% [markdown]
# ## Задание 9
#
# Проведите аналитику по данным находящимся в таблице `Задание_9_Excel.xlsx` по следующим пунктам
#
# 1. Вывести суммарную просрочку
# 2. Вывести максимум по просрочке
# 3. В столбце "Уровень ПЗ" рассчитать отношение просрочки к выдачам
# 4. Посчитать кол-во строк, где в поле "Тип данных" указана Москва
# 5. Вывести суммарные выдачи за 30.06
# 6. В столбец ФЛАГ 0+ 3-4 возраст вывести `Да` если тип просрочки 0+ 3-4 возраст, если нет, то вывести `Нет`
