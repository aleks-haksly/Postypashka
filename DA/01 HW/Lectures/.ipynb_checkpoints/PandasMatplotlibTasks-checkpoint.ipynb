# %%
# Всё необходимое для выполнения данной лабораторной работы!
import requests
from time import sleep

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
pd.set_option('display.max_columns', 100)

# %% [markdown]
# ## Задание 1. Парсинг - 10 баллов

# %% [markdown]
# В этом задании Вам предстоит работать с API сайта <a target="_blank" href="hh.ru">hh.ru</a>. Документация доступна по <a target="_blank" href="https://github.com/hhru/api/blob/master/docs/vacancies.md#search">ссылке</a>.

# %% [markdown]
# **Задача:**
# 1. выбрать 5 интересующих вас профессий (не смежных, т.е. Аналатик и Data Engineer не считается корректным)
# 2. затем получить доступные по данным профессиям вакансии в Москве и выделить их физические координаты
# 3. нанести полученные координаты на карту местоположения компаний

# %%
URL_areas = 'https://api.hh.ru/areas'
URL_professions = 'https://api.hh.ru/professional_roles'
URL_vacancies = 'https://api.hh.ru/vacancies'

# %%
data_areas = requests.get(URL_areas).json()
data_professions = requests.get(URL_professions).json()

# %%
def get_city_id_by_name(data:dict=data_areas, county_name:str='Россия', city_name:str='Москва') -> str | None:
    """
    Returns the city ID given a country name and city name.

    :param data: A dictionary containing country and city data.
    :param county_name: The name of the country.
    :param city_name: The name of the city.
    :return: The ID of the city if found, otherwise None
    """
    for country in data_areas:
        if country.get('name', []) == county_name:
            for city in country['areas']:
                if city.get('name', []) == city_name:
                    return city.get('id', None)

# %%
def get_random_professions_names(data:dict=data_professions, n:int=5) -> list:
    """
    Returns a list of random profession names.

    :param data: A dictionary containing professions data.
    :param n: The number of profession names to return.
    :return: A list of random profession names
    """
    result = []
    profession_categories = [profession_categories.get('name') for profession_categories in data.get('categories')][:-1] #Категорию "другое" не рассматриваем
    # Выберем по 1 случайной профессии из n случайных категорий
    for profession_category in np.random.choice(profession_categories, size=n, replace=False):
        for profession in data_professions.get('categories'):
            if profession.get('name', []) == profession_category:
                result.append(np.random.choice(profession.get('roles'), size=1, replace=False)[0].get('name'))
                break
    return result

# %%
np.random.seed(42)
get_random_professions_names()
# Out:
# ['Артист, актер, аниматор',
#  'Агроном',
#  'Автомойщик',
#  'Финансовый директор (CFO)',
#  'Психолог']

# %% [markdown]
# *Пример запроса для профессии:*

# %%
def get_vacancies_page(vacancy_name, page=0, city='Москва'):

    params = {
        'text': vacancy_name,
        'area': get_city_id_by_name(city_name=city),
        'page': page,
        'per_page': 10
    }
    return requests.get(URL_vacancies, params).json()

# %%
def get_vacancies(vacancy_name, city='Москва'):
    page = 0
    current_page = get_vacancies_page(vacancy_name=vacancy_name, page=page, city=city)
    vacancies = []
    while current_page.get('pages') > page:
        vacancies.append(current_page.get('items'))
        page += 1
        current_page = get_vacancies_page(vacancy_name=vacancy_name, page=page, city=city)
        sleep(0.5)
    return {'items': vacancies, 'found': current_page.get('found')}
    #return {'items': [item for sublist in vacancies for item in sublist], 'found': current_page.get('found')}

# %%
vacancies_data = get_vacancies(vacancy_name='Агроном')

# %%
vacancies_data
# Out:
# {'items': [[{'id': '107214681',
#     'premium': False,
#     'name': 'Главный агроном',
#     'department': None,
#     'has_test': False,
#     'response_letter_required': False,
#     'area': {'id': '1', 'name': 'Москва', 'url': 'https://api.hh.ru/areas/1'},
#     'salary': {'from': 180000, 'to': None, 'currency': 'RUR', 'gross': False},
#     'type': {'id': 'open', 'name': 'Открытая'},
#     'address': None,
#     'response_url': None,
#     'sort_point_distance': None,
#     'published_at': '2024-09-12T17:36:02+0300',
#     'created_at': '2024-09-12T17:36:02+0300',
#     'archived': False,
#     'apply_alternate_url': 'https://hh.ru/applicant/vacancy_response?vacancyId=107214681',
#     'show_logo_in_search': None,
#     'insider_interview': None,
#     'url': 'https://api.hh.ru/vacancies/107214681?host=hh.ru',
#     'alternate_url': 'https://hh.ru/vacancy/107214681',
#     'relations': [],
#     'employer': {'id': '1069209',
#      'name': 'Кадровый центр Президент',
#      'url': 'https://api.hh.ru/employers/1069209',
#      'alternate_url': 'https://hh.ru/employer/1069209',
#      'logo_urls': {'90': 'https://img.hhcdn.ru/employer-logo/6501065.jpeg',
#       '240': 'https://img.hhcdn.ru/employer-logo/6501066.jpeg',
#       'original': 'https://img.hhcdn.ru/employer-logo-original/1220156.jpg'},
#      'vacancies_url': 'https://api.hh.ru/vacancies?employer_id=1069209',
#      'accredited_it_employer': False,
#      'trusted': True},
#     'snippet': {'requirement': 'Высшее профильное образование. Знание декоративных растений и их агротехники. Наличие управленческого опыта. Навыки в сфере ландшафтно /паркового озеленения от 3...',
#      'responsibility': 'Организация работы всех структурных подразделений питомника. Планирование и организация производственного процесса по выращиванию и уходу за растениями. Составление отчётности, ведение...'},
#     'contacts': None,
#     'schedule': {'id': 'fullDay', 'name': 'Полный день'},
#     'working_days': [],
#     'working_time_intervals': [],
#     'working_time_modes': [],
#     'accept_temporary': False,
#     'professional_roles': [{'id': '7', 'name': 'Агроном'}],
#     'accept_incomplete_resumes': False,
#     'experience': {'id': 'between3And6', 'name': 'От 3 до 6 лет'},
#     'employment': {'id': 'full', 'name': 'Полная занятость'},
#     'adv_response_url': None,
#     'is_adv_vacancy': False,
#     'adv_context': None},
#    {'id': '106335339',
#     'premium': False,
#     'name': 'Управляющий агрофермой (Агроном) релокация на Бали',
#     'department': None,
#     'has_test': False,
#     'response_letter_required': True,
#     'area': {'id': '1', 'name': 'Москва', 'url': 'https://api.hh.ru/areas/1'},
#     'salary': {'from': 2000, 'to': None, 'currency': 'USD', 'gross': True},
#     'type': {'id': 'open', 'name': 'Открытая'},
#     'address': None,
#     'response_url': None,
#     'sort_point_distance': None,
#     'published_at': '2024-08-26T14:39:27+0300',
#     'created_at': '2024-08-26T14:39:27+0300',
#     'archived': False,
#     'apply_alternate_url': 'https://hh.ru/applicant/vacancy_response?vacancyId=106335339',
#     'show_logo_in_search': None,
#     'insider_interview': None,
#     'url': 'https://api.hh.ru/vacancies/106335339?host=hh.ru',
#     'alternate_url': 'https://hh.ru/vacancy/106335339',
#     'relations': [],
#     'employer': {'id': '11217206',
#      'name': 'Всё, я увольняюсь!',
#      'url': 'https://api.hh.ru/employers/11217206',
#      'alternate_url': 'https://hh.ru/employer/11217206',
#      'logo_urls': {'240': 'https://img.hhcdn.ru/employer-logo/6932655.jpeg',
#       'original': 'https://img.hhcdn.ru/employer-logo-original/1328158.jpeg',
#       '90': 'https://img.hhcdn.ru/employer-logo/6932654.jpeg'},
#      'vacancies_url': 'https://api.hh.ru/vacancies?employer_id=11217206',
#      'accredited_it_employer': False,
#      'trusted': True},
#     'snippet': {'requirement': 'Профильное образование. Релевантный опыт работы. Не только разбираться, но и любить свою профессию.',
#      'responsibility': 'Контроль расходов и доходов, быстрая реакция на изменения и решение проблем. Настройка и регулировка параметров парников (влажность, температура, борьба с...'},
#     'contacts': None,
#     'schedule': {'id': 'fullDay', 'name': 'Полный день'},
#     'working_days': [],
#     'working_time_intervals': [],
#     'working_time_modes': [],
#     'accept_temporary': False,
#     'professional_roles': [{'id': '7', 'name': 'Агроном'}],
#     'accept_incomplete_resumes': False,
#     'experience': {'id': 'between3And6', 'name': 'От 3 до 6 лет'},
#     'employment': {'id': 'full', 'name': 'Полная занятость'},
#     'adv_response_url': None,
#     'is_adv_vacancy': False,
#     'adv_context': None},
#    {'id': '106435824',
#     'premium': False,
#     'name': 'Ландшафтный дизайнер/Садовник/Дендролог/Агроном',
#     'department': None,
#     'has_test': False,
#     'response_letter_required': False,
#     'area': {'id': '1', 'name': 'Москва', 'url': 'https://api.hh.ru/areas/1'},
#     'salary': {'from': 180000, 'to': None, 'currency': 'RUR', 'gross': False},
#     'type': {'id': 'open', 'name': 'Открытая'},
#     'address': None,
#     'response_url': None,
#     'sort_point_distance': None,
#     'published_at': '2024-09-02T10:32:17+0300',
#     'created_at': '2024-09-02T10:32:17+0300',
#     'archived': False,
#     'apply_alternate_url': 'https://hh.ru/applicant/vacancy_response?vacancyId=106435824',
#     'show_logo_in_search': None,
#     'insider_interview': None,
#     'url': 'https://api.hh.ru/vacancies/106435824?host=hh.ru',
#     'alternate_url': 'https://hh.ru/vacancy/106435824',
#     'relations': [],
#     'employer': {'id': '56479',
#      'name': 'Дэстэн Партнерс',
#      'url': 'https://api.hh.ru/employers/56479',
#      'alternate_url': 'https://hh.ru/employer/56479',
#      'logo_urls': {'240': 'https://img.hhcdn.ru/employer-logo/6825003.jpeg',
#       '90': 'https://img.hhcdn.ru/employer-logo/6825002.jpeg',
#       'original': 'https://img.hhcdn.ru/employer-logo-original/1301185.jpg'},
#      'vacancies_url': 'https://api.hh.ru/vacancies?employer_id=56479',
#      'accredited_it_employer': False,
#      'trusted': True},
#     'snippet': {'requirement': 'Опыт работы в смежной должности.',
#      'responsibility': 'Выезды к клиентам. 2-3 выезда в день (50-70 км от МКАДа). Анализ участка. Описывать фронт работы.'},
#     'contacts': None,
#     'schedule': {'id': 'fullDay', 'name': 'Полный день'},
#     'working_days': [],
#     'working_time_intervals': [],
#     'working_time_modes': [],
#     'accept_temporary': False,
#     'professional_roles': [{'id': '34', 'name': 'Дизайнер, художник'}],
#     'accept_incomplete_resumes': False,
#     'experience': {'id': 'between1And3', 'name': 'От 1 года до 3 лет'},
#     'employment': {'id': 'full', 'name': 'Полная занятость'},
#     'adv_response_url': None,
#     'is_adv_vacancy': False,
#     'adv_context': None},
#    {'id': '106918725',
#     'premium': False,
#     'name': 'Агроном',
#     'department': None,
#     'has_test': False,
#     'response_letter_required': False,
#     'area': {'id': '1', 'name': 'Москва', 'url': 'https://api.hh.ru/areas/1'},
#     'salary': {'from': 30000, 'to': 40000, 'currency': 'RUR', 'gross': False},
#     'type': {'id': 'open', 'name': 'Открытая'},
#     'address': {'city': 'Москва',
#      'street': 'улица Плеханова',
#      'building': '10',
#      'lat': 55.750226,
#      'lng': 37.760045,
#      'description': None,
#      'raw': 'Москва, улица Плеханова, 10',
#      'metro': {'station_name': 'Перово',
#       'line_name': 'Калининская',
#       'station_id': '8.107',
#       'line_id': '8',
#       'lat': 55.75098,
#       'lng': 37.78422},
#      'metro_stations': [{'station_name': 'Перово',
#        'line_name': 'Калининская',
#        'station_id': '8.107',
#        'line_id': '8',
#        'lat': 55.75098,
#        'lng': 37.78422}],
#      'id': '16486141'},
#     'response_url': None,
#     'sort_point_distance': None,
#     'published_at': '2024-09-06T16:36:22+0300',
#     'created_at': '2024-09-06T16:36:22+0300',
#     'archived': False,
#     'apply_alternate_url': 'https://hh.ru/applicant/vacancy_response?vacancyId=106918725',
#     'show_logo_in_search': None,
#     'insider_interview': None,
#     'url': 'https://api.hh.ru/vacancies/106918725?host=hh.ru',
#     'alternate_url': 'https://hh.ru/vacancy/106918725',
#     'relations': [],
#     'employer': {'id': '11412752',
#      'name': 'Здоровый Сад',
#      'url': 'https://api.hh.ru/employers/11412752',
#      'alternate_url': 'https://hh.ru/employer/11412752',
#      'logo_urls': {'original': 'https://img.hhcdn.ru/employer-logo-original/1328952.png',
#       '90': 'https://img.hhcdn.ru/employer-logo/6935826.png',
#       '240': 'https://img.hhcdn.ru/employer-logo/6935827.png'},
#      'vacancies_url': 'https://api.hh.ru/vacancies?employer_id=11412752',
#      'accredited_it_employer': False,
#      'trusted': True},
#     'snippet': {'requirement': 'Ответственность. Кропотливость. Внимательность. Способность брать на себя дополнительную работу (при необходимости) за отдельную плату - (например настроить стеллаж, подключить лампы, сделать...',
#      'responsibility': 'Выращивание таких культур как : микрозелень, бейби зелень, пищевые цветы, пряные травы. Знания в растениеводстве. Поддержание микроклимата в помещении. '},
#     'contacts': None,
#     'schedule': {'id': 'fullDay', 'name': 'Полный день'},
#     'working_days': [],
#     'working_time_intervals': [],
#     'working_time_modes': [],
#     'accept_temporary': True,
#     'professional_roles': [{'id': '7', 'name': 'Агроном'}],
#     'accept_incomplete_resumes': False,
#     'experience': {'id': 'between1And3', 'name': 'От 1 года до 3 лет'},
#     'employment': {'id': 'part', 'name': 'Частичная занятость'},
#     'adv_response_url': None,
#     'is_adv_vacancy': False,
#     'adv_context': None},
#    {'id': '105672373',
#     'premium': False,
#     'name': 'Агроном/овощевод',
#     'department': None,
#     'has_test': False,
#     'response_letter_required': False,
#     'area': {'id': '1', 'name': 'Москва', 'url': 'https://api.hh.ru/areas/1'},
#     'salary': {'from': 120000, 'to': None, 'currency': 'RUR', 'gross': False},
#     'type': {'id': 'open', 'name': 'Открытая'},
#     'address': None,
#     'response_url': None,
#     'sort_point_distance': None,
#     'published_at': '2024-08-28T12:27:02+0300',
#     'created_at': '2024-08-28T12:27:02+0300',
#     'archived': False,
#     'apply_alternate_url': 'https://hh.ru/applicant/vacancy_response?vacancyId=105672373',
#     'show_logo_in_search': None,
#     'insider_interview': None,
#     'url': 'https://api.hh.ru/vacancies/105672373?host=hh.ru',
#     'alternate_url': 'https://hh.ru/vacancy/105672373',
#     'relations': [],
#     'employer': {'id': '2161246',
#      'name': 'МОСМАКС ТРЕТЬЯКОВСКИЙ',
#      'url': 'https://api.hh.ru/employers/2161246',
#      'alternate_url': 'https://hh.ru/employer/2161246',
#      'logo_urls': {'240': 'https://img.hhcdn.ru/employer-logo/4088820.png',
#       '90': 'https://img.hhcdn.ru/employer-logo/4088819.png',
#       'original': 'https://img.hhcdn.ru/employer-logo-original/912033.png'},
#      'vacancies_url': 'https://api.hh.ru/vacancies?employer_id=2161246',
#      'accredited_it_employer': False,
#      'trusted': True},
#     'snippet': {'requirement': 'Честность, добросовестность, навыки и опыт работы в сельском хозяйстве.',
#      'responsibility': 'Работа в закрытом и открытом грунте. Посадка овощных культур и уход за ними (помидоры, огурцы).'},
#     'contacts': None,
#     'schedule': {'id': 'fullDay', 'name': 'Полный день'},
#     'working_days': [],
#     'working_time_intervals': [],
#     'working_time_modes': [],
#     'accept_temporary': False,
#     'professional_roles': [{'id': '7', 'name': 'Агроном'}],
#     'accept_incomplete_resumes': True,
#     'experience': {'id': 'between1And3', 'name': 'От 1 года до 3 лет'},
#     'employment': {'id': 'full', 'name': 'Полная занятость'},
#     'adv_response_url': None,
#     'is_adv_vacancy': False,
#     'adv_context': None},
#    {'id': '106066250',
#     'premium': False,
#     'name': 'Биолог/специалист по уходу за горшечными растениями',
#     'department': None,
#     'has_test': False,
#     'response_letter_required': False,
#     'area': {'id': '1', 'name': 'Москва', 'url': 'https://api.hh.ru/areas/1'},
#     'salary': {'from': 35000, 'to': 68000, 'currency': 'RUR', 'gross': False},
#     'type': {'id': 'open', 'name': 'Открытая'},
#     'address': {'city': 'деревня Аносино',
#      'street': 'Университетская улица',
#      'building': 'вл11',
#      'lat': 55.844809,
#      'lng': 37.006161,
#      'description': None,
#      'raw': 'деревня Аносино, Университетская улица, вл11',
#      'metro': None,
#      'metro_stations': [],
#      'id': '16364377'},
#     'response_url': None,
#     'sort_point_distance': None,
#     'published_at': '2024-08-20T14:14:14+0300',
#     'created_at': '2024-08-20T14:14:14+0300',
#     'archived': False,
#     'apply_alternate_url': 'https://hh.ru/applicant/vacancy_response?vacancyId=106066250',
#     'show_logo_in_search': None,
#     'insider_interview': None,
#     'url': 'https://api.hh.ru/vacancies/106066250?host=hh.ru',
#     'alternate_url': 'https://hh.ru/vacancy/106066250',
#     'relations': [],
#     'employer': {'id': '787380',
#      'name': 'Бюро Фитодизайна Фикус',
#      'url': 'https://api.hh.ru/employers/787380',
#      'alternate_url': 'https://hh.ru/employer/787380',
#      'logo_urls': {'original': 'https://img.hhcdn.ru/employer-logo-original/941072.png',
#       '240': 'https://img.hhcdn.ru/employer-logo/4204829.png',
#       '90': 'https://img.hhcdn.ru/employer-logo/4204828.png'},
#      'vacancies_url': 'https://api.hh.ru/vacancies?employer_id=787380',
#      'accredited_it_employer': False,
#      'trusted': True},
#     'snippet': {'requirement': 'Организованность. Высокая ответственность. Пунктуальность. Аккуратность. Внимательность. Будет преимуществом профильное образование (<highlighttext>агроном</highlighttext>, почвовед, агрохимик, ландшафтный архитектор, садовод, биолог, лесное дело и...',
#      'responsibility': 'Комплексный уход за растениями включает в себя: -полив растений. -удаление пыли с листьев. -формирование кроны. -подсыпка грунта. -своевременная диагностика болезней...'},
#     'contacts': None,
#     'schedule': {'id': 'fullDay', 'name': 'Полный день'},
#     'working_days': [],
#     'working_time_intervals': [],
#     'working_time_modes': [],
#     'accept_temporary': False,
#     'professional_roles': [{'id': '40', 'name': 'Другое'}],
#     'accept_incomplete_resumes': True,
#     'experience': {'id': 'between1And3', 'name': 'От 1 года до 3 лет'},
#     'employment': {'id': 'full', 'name': 'Полная занятость'},
#     'adv_response_url': None,
#     'is_adv_vacancy': False,
#     'adv_context': None},
#    {'id': '106702001',
#     'premium': False,
#     'name': 'Агроном (Растениеводство)',
#     'department': None,
#     'has_test': False,
#     'response_letter_required': False,
#     'area': {'id': '1', 'name': 'Москва', 'url': 'https://api.hh.ru/areas/1'},
#     'salary': {'from': 130000,
#      'to': 150000,
#      'currency': 'RUR',
#      'gross': False},
#     'type': {'id': 'open', 'name': 'Открытая'},
#     'address': {'city': 'деревня Кончинка',
#      'street': None,
#      'building': None,
#      'lat': 54.678276,
#      'lng': 38.157702,
#      'description': None,
#      'raw': 'деревня Кончинка',
#      'metro': None,
#      'metro_stations': [],
#      'id': '1889665'},
#     'response_url': None,
#     'sort_point_distance': None,
#     'published_at': '2024-09-12T11:55:28+0300',
#     'created_at': '2024-09-12T11:55:28+0300',
#     'archived': False,
#     'apply_alternate_url': 'https://hh.ru/applicant/vacancy_response?vacancyId=106702001',
#     'show_logo_in_search': None,
#     'insider_interview': None,
#     'url': 'https://api.hh.ru/vacancies/106702001?host=hh.ru',
#     'alternate_url': 'https://hh.ru/vacancy/106702001',
#     'relations': [],
#     'employer': {'id': '161720',
#      'name': 'КОРНИ, Питомник растений',
#      'url': 'https://api.hh.ru/employers/161720',
#      'alternate_url': 'https://hh.ru/employer/161720',
#      'logo_urls': {'240': 'https://img.hhcdn.ru/employer-logo/2772456.png',
#       '90': 'https://img.hhcdn.ru/employer-logo/2772455.png',
#       'original': 'https://img.hhcdn.ru/employer-logo-original/582800.png'},
#      'vacancies_url': 'https://api.hh.ru/vacancies?employer_id=161720',
#      'accredited_it_employer': False,
#      'trusted': True},
#     'snippet': {'requirement': 'Опыт работы в питомнике, садовом центре или овощеводческом предприятии от 3 лет. Опыт работы на руководящей должности (начальник, бригадир и...',
#      'responsibility': 'Организовывать процесса размножения и выращивания декоративных растений. Внедрять и контролировать соблюдение технологий выращивания растений. Своевременное выявлять болезни, вредителей в почве...'},
#     'contacts': None,
#     'schedule': {'id': 'fullDay', 'name': 'Полный день'},
#     'working_days': [],
#     'working_time_intervals': [],
#     'working_time_modes': [],
#     'accept_temporary': True,
#     'professional_roles': [{'id': '7', 'name': 'Агроном'}],
#     'accept_incomplete_resumes': True,
#     'experience': {'id': 'between3And6', 'name': 'От 3 до 6 лет'},
#     'employment': {'id': 'full', 'name': 'Полная занятость'},
#     'adv_response_url': None,
#     'is_adv_vacancy': False,
#     'adv_context': None},
#    {'id': '107065128',
#     'premium': False,
#     'name': 'Специалист по уходу за офисными растениями (садовник-агроном / биолог-фитопатолог)',
#     'department': None,
#     'has_test': False,
#     'response_letter_required': False,
#     'area': {'id': '1', 'name': 'Москва', 'url': 'https://api.hh.ru/areas/1'},
#     'salary': {'from': 25000, 'to': 100000, 'currency': 'RUR', 'gross': False},
#     'type': {'id': 'open', 'name': 'Открытая'},
#     'address': {'city': 'Москва',
#      'street': 'Пресненская набережная',
#      'building': '12',
#      'lat': 55.749633,
#      'lng': 37.537434,
#      'description': None,
#      'raw': 'Москва, Пресненская набережная, 12',
#      'metro': {'station_name': 'Деловой центр',
#       'line_name': 'Солнцевская',
#       'station_id': '133.468',
#       'line_id': '133',
#       'lat': 55.7491,
#       'lng': 37.5395},
#      'metro_stations': [{'station_name': 'Деловой центр',
#        'line_name': 'Солнцевская',
#        'station_id': '133.468',
#        'line_id': '133',
#        'lat': 55.7491,
#        'lng': 37.5395}],
#      'id': '11920647'},
#     'response_url': None,
#     'sort_point_distance': None,
#     'published_at': '2024-09-10T15:15:41+0300',
#     'created_at': '2024-09-10T15:15:41+0300',
#     'archived': False,
#     'apply_alternate_url': 'https://hh.ru/applicant/vacancy_response?vacancyId=107065128',
#     'insider_interview': None,
#     'url': 'https://api.hh.ru/vacancies/107065128?host=hh.ru',
#     'alternate_url': 'https://hh.ru/vacancy/107065128',
#     'relations': [],
#     'employer': {'id': '3926338',
#      'name': 'Дизайн Инжиниринг',
#      'url': 'https://api.hh.ru/employers/3926338',
#      'alternate_url': 'https://hh.ru/employer/3926338',
#      'logo_urls': None,
#      'vacancies_url': 'https://api.hh.ru/vacancies?employer_id=3926338',
#      'accredited_it_employer': False,
#      'trusted': True},
#     'snippet': {'requirement': 'Диплом об профильном образовании (высшее, минимум среднее специальное). Опыт работы от 1 лет обязателен.',
#      'responsibility': 'Комплексный уход за офисными растениями. Знание болезней и вредителей растений. Умение вести профилактическую работу с растениями. Подбор эффективного лечения растений...'},
#     'contacts': None,
#     'schedule': {'id': 'flexible', 'name': 'Гибкий график'},
#     'working_days': [],
#     'working_time_intervals': [{'id': 'from_four_to_six_hours_in_a_day',
#       'name': 'Можно сменами по\xa04-6\xa0часов в\xa0день'}],
#     'working_time_modes': [],
#     'accept_temporary': True,
#     'professional_roles': [{'id': '7', 'name': 'Агроном'}],
#     'accept_incomplete_resumes': False,
#     'experience': {'id': 'between1And3', 'name': 'От 1 года до 3 лет'},
#     'employment': {'id': 'part', 'name': 'Частичная занятость'},
#     'adv_response_url': None,
#     'is_adv_vacancy': False,
#     'adv_context': None},
#    {'id': '106267536',
#     'premium': False,
#     'name': 'Агроном',
#     'department': None,
#     'has_test': False,
#     'response_letter_required': False,
#     'area': {'id': '1', 'name': 'Москва', 'url': 'https://api.hh.ru/areas/1'},
#     'salary': {'from': 80000, 'to': None, 'currency': 'RUR', 'gross': False},
#     'type': {'id': 'open', 'name': 'Открытая'},
#     'address': None,
#     'response_url': None,
#     'sort_point_distance': None,
#     'published_at': '2024-09-10T15:49:41+0300',
#     'created_at': '2024-09-10T15:49:41+0300',
#     'archived': False,
#     'apply_alternate_url': 'https://hh.ru/applicant/vacancy_response?vacancyId=106267536',
#     'show_logo_in_search': None,
#     'insider_interview': None,
#     'url': 'https://api.hh.ru/vacancies/106267536?host=hh.ru',
#     'alternate_url': 'https://hh.ru/vacancy/106267536',
#     'relations': [],
#     'employer': {'id': '1197490',
#      'name': 'Озеленитель Стройгруп',
#      'url': 'https://api.hh.ru/employers/1197490',
#      'alternate_url': 'https://hh.ru/employer/1197490',
#      'logo_urls': {'original': 'https://img.hhcdn.ru/employer-logo-original/58989.jpg',
#       '90': 'https://img.hhcdn.ru/employer-logo/875324.jpeg',
#       '240': 'https://img.hhcdn.ru/employer-logo/875325.jpeg'},
#      'vacancies_url': 'https://api.hh.ru/vacancies?employer_id=1197490',
#      'accredited_it_employer': False,
#      'trusted': True},
#     'snippet': {'requirement': 'Образование не ниже среднего специального (агрономия). Мы готовы рассмотреть выпускников ВУЗов по направлению агрономии, садоводства, лесного дела и кандидатов с...',
#      'responsibility': 'Все виды работ на объектах по уходу за плодовыми, хвойными, декоративно-лиственными, кустарниковыми и цветочными насаждениями. Посадка и пересадка растений. '},
#     'contacts': None,
#     'schedule': {'id': 'fullDay', 'name': 'Полный день'},
#     'working_days': [],
#     'working_time_intervals': [],
#     'working_time_modes': [],
#     'accept_temporary': False,
#     'professional_roles': [{'id': '7', 'name': 'Агроном'}],
#     'accept_incomplete_resumes': False,
#     'experience': {'id': 'noExperience', 'name': 'Нет опыта'},
#     'employment': {'id': 'full', 'name': 'Полная занятость'},
#     'adv_response_url': None,
#     'is_adv_vacancy': False,
#     'adv_context': None},
#    {'id': '92590473',
#     'premium': False,
#     'name': 'Специалист по сертификации (сельское хозяйство)',
#     'department': None,
#     'has_test': False,
#     'response_letter_required': False,
#     'area': {'id': '1', 'name': 'Москва', 'url': 'https://api.hh.ru/areas/1'},
#     'salary': {'from': None, 'to': 120000, 'currency': 'RUR', 'gross': True},
#     'type': {'id': 'open', 'name': 'Открытая'},
#     'address': {'city': 'Москва',
#      'street': 'Большой Трёхгорный переулок',
#      'building': '1/26с7',
#      'lat': 55.757602,
#      'lng': 37.563063,
#      'description': None,
#      'raw': 'Москва, Большой Трёхгорный переулок, 1/26с7',
#      'metro': {'station_name': 'Улица 1905 года',
#       'line_name': 'Таганско-Краснопресненская',
#       'station_id': '7.146',
#       'line_id': '7',
#       'lat': 55.763944,
#       'lng': 37.562271},
#      'metro_stations': [{'station_name': 'Улица 1905 года',
#        'line_name': 'Таганско-Краснопресненская',
#        'station_id': '7.146',
#        'line_id': '7',
#        'lat': 55.763944,
#        'lng': 37.562271}],
#      'id': '6854575'},
#     'response_url': None,
#     'sort_point_distance': None,
#     'published_at': '2024-08-25T17:58:20+0300',
#     'created_at': '2024-08-25T17:58:20+0300',
#     'archived': False,
#     'apply_alternate_url': 'https://hh.ru/applicant/vacancy_response?vacancyId=92590473',
#     'branding': {'type': 'MAKEUP', 'tariff': None},
#     'show_logo_in_search': True,
#     'insider_interview': None,
#     'url': 'https://api.hh.ru/vacancies/92590473?host=hh.ru',
#     'alternate_url': 'https://hh.ru/vacancy/92590473',
#     'relations': [],
#     'employer': {'id': '5730496',
#      'name': 'Major Agro',
#      'url': 'https://api.hh.ru/employers/5730496',
#      'alternate_url': 'https://hh.ru/employer/5730496',
#      'logo_urls': {'original': 'https://img.hhcdn.ru/employer-logo-original/1071109.png',
#       '240': 'https://img.hhcdn.ru/employer-logo/5905066.png',
#       '90': 'https://img.hhcdn.ru/employer-logo/5905065.png'},
#      'vacancies_url': 'https://api.hh.ru/vacancies?employer_id=5730496',
#      'accredited_it_employer': False,
#      'trusted': True},
#     'snippet': {'requirement': 'Высшее/среднее специальное профильное образование (<highlighttext>агроном</highlighttext>, <highlighttext>агроном</highlighttext>-эколог и т.д.). Стаж работы от 1 года желателен. Уверенный пользователь MS...',
#      'responsibility': 'Проведение работ по сертификации органической продукции (ГОСТ 33980-2016, ГОСТ Р 57022–2016, ГОСТ Р 56104-2014, Европейский Регламент 2018...'},
#     'contacts': None,
#     'schedule': {'id': 'fullDay', 'name': 'Полный день'},
#     'working_days': [],
#     'working_time_intervals': [],
#     'working_time_modes': [],
#     'accept_temporary': False,
#     'professional_roles': [{'id': '151',
#       'name': 'Специалист по сертификации'}],
#     'accept_incomplete_resumes': False,
#     'experience': {'id': 'between1And3', 'name': 'От 1 года до 3 лет'},
#     'employment': {'id': 'full', 'name': 'Полная занятость'},
#     'adv_response_url': None,
#     'is_adv_vacancy': False,
#     'adv_context': None}],
#   [{'id': '106107473',
#     'premium': False,
#     'name': 'Агроном',
#     'department': None,
#     'has_test': False,
#     'response_letter_required': False,
#     'area': {'id': '1', 'name': 'Москва', 'url': 'https://api.hh.ru/areas/1'},
#     'salary': {'from': 50000, 'to': 100000, 'currency': 'RUR', 'gross': False},
#     'type': {'id': 'open', 'name': 'Открытая'},
#     'address': None,
#     'response_url': None,
#     'sort_point_distance': None,
#     'published_at': '2024-08-21T11:17:36+0300',
#     'created_at': '2024-08-21T11:17:36+0300',
#     'archived': False,
#     'apply_alternate_url': 'https://hh.ru/applicant/vacancy_response?vacancyId=106107473',
#     'show_logo_in_search': None,
#     'insider_interview': None,
#     'url': 'https://api.hh.ru/vacancies/106107473?host=hh.ru',
#     'alternate_url': 'https://hh.ru/vacancy/106107473',
#     'relations': [],
#     'employer': {'id': '10797718',
#      'name': 'Райдер СНГ',
#      'url': 'https://api.hh.ru/employers/10797718',
#      'alternate_url': 'https://hh.ru/employer/10797718',
#      'logo_urls': {'original': 'https://img.hhcdn.ru/employer-logo-original/1255026.png',
#       '90': 'https://img.hhcdn.ru/employer-logo/6640533.png',
#       '240': 'https://img.hhcdn.ru/employer-logo/6640534.png'},
#      'vacancies_url': 'https://api.hh.ru/vacancies?employer_id=10797718',
#      'accredited_it_employer': False,
#      'trusted': True},
#     'snippet': {'requirement': 'Tребовaния к вaм:  Bысшee или сpедне-cпециaльное агpономическое/агрохимическое образование.  Знание технологии выращивания овощей и цветов.  Опыт работы желателен, но...',
#      'responsibility': 'Рaйдер Cидc – производственная cелeкционно-cеменовoдчеcкaя кoмпaния, являющaяcя надежным поcтaвщикoм семян овoщныx культуp ищeт aгрoнoмa Готовы рассмотреть в том числе кандидата...'},
#     'contacts': None,
#     'schedule': {'id': 'fullDay', 'name': 'Полный день'},
#     'working_days': [],
#     'working_time_intervals': [],
#     'working_time_modes': [],
#     'accept_temporary': False,
#     'professional_roles': [{'id': '7', 'name': 'Агроном'}],
#     'accept_incomplete_resumes': False,
#     'experience': {'id': 'noExperience', 'name': 'Нет опыта'},
#     'employment': {'id': 'full', 'name': 'Полная занятость'},
#     'adv_response_url': None,
#     'is_adv_vacancy': False,
#     'adv_context': None},
#    {'id': '106910336',
#     'premium': False,
#     'name': 'Агроном',
#     'department': None,
#     'has_test': False,
#     'response_letter_required': False,
#     'area': {'id': '1', 'name': 'Москва', 'url': 'https://api.hh.ru/areas/1'},
#     'salary': {'from': 88000, 'to': None, 'currency': 'RUR', 'gross': False},
#     'type': {'id': 'open', 'name': 'Открытая'},
#     'address': {'city': 'село Ильинское',
#      'street': 'Экспериментальная улица',
#      'building': '14',
#      'lat': 55.762115,
#      'lng': 37.229132,
#      'description': None,
#      'raw': 'село Ильинское, Экспериментальная улица, 14',
#      'metro': None,
#      'metro_stations': [],
#      'id': '15001429'},
#     'response_url': None,
#     'sort_point_distance': None,
#     'published_at': '2024-09-06T14:36:02+0300',
#     'created_at': '2024-09-06T14:36:02+0300',
#     'archived': False,
#     'apply_alternate_url': 'https://hh.ru/applicant/vacancy_response?vacancyId=106910336',
#     'show_logo_in_search': None,
#     'insider_interview': None,
#     'url': 'https://api.hh.ru/vacancies/106910336?host=hh.ru',
#     'alternate_url': 'https://hh.ru/vacancy/106910336',
#     'relations': [],
#     'employer': {'id': '4438089',
#      'name': 'ЭкоПлантТ',
#      'url': 'https://api.hh.ru/employers/4438089',
#      'alternate_url': 'https://hh.ru/employer/4438089',
#      'logo_urls': {'90': 'https://img.hhcdn.ru/employer-logo/6764678.jpeg',
#       'original': 'https://img.hhcdn.ru/employer-logo-original/1286095.jpeg',
#       '240': 'https://img.hhcdn.ru/employer-logo/6764679.jpeg'},
#      'vacancies_url': 'https://api.hh.ru/vacancies?employer_id=4438089',
#      'accredited_it_employer': False,
#      'trusted': True},
#     'snippet': {'requirement': 'Опыт работы агрономом или садовником, возможно выпускник по специальностям связанным с агрономией, без опыта работы. Всесторонние знания в области агрономии...',
#      'responsibility': 'Организация и проведение работ по: Дендрологическим обследованиям зеленых насаждений, контролю за посадкой декоративных растений и крупномеров. Проведению посадочных мероприятий; контролю...'},
#     'contacts': None,
#     'schedule': {'id': 'fullDay', 'name': 'Полный день'},
#     'working_days': [],
#     'working_time_intervals': [],
#     'working_time_modes': [],
#     'accept_temporary': False,
#     'professional_roles': [{'id': '7', 'name': 'Агроном'}],
#     'accept_incomplete_resumes': True,
#     'experience': {'id': 'between1And3', 'name': 'От 1 года до 3 лет'},
#     'employment': {'id': 'full', 'name': 'Полная занятость'},
#     'adv_response_url': None,
#     'is_adv_vacancy': False,
#     'adv_context': None},
#    {'id': '106773968',
#     'premium': False,
#     'name': 'Садовник-агроном (м. Ботанический сад)',
#     'department': None,
#     'has_test': False,
#     'response_letter_required': False,
#     'area': {'id': '1', 'name': 'Москва', 'url': 'https://api.hh.ru/areas/1'},
#     'salary': {'from': 80000, 'to': 80000, 'currency': 'RUR', 'gross': False},
#     'type': {'id': 'open', 'name': 'Открытая'},
#     'address': None,
#     'response_url': None,
#     'sort_point_distance': None,
#     'published_at': '2024-09-04T12:57:31+0300',
#     'created_at': '2024-09-04T12:57:31+0300',
#     'archived': False,
#     'apply_alternate_url': 'https://hh.ru/applicant/vacancy_response?vacancyId=106773968',
#     'show_logo_in_search': None,
#     'insider_interview': None,
#     'url': 'https://api.hh.ru/vacancies/106773968?host=hh.ru',
#     'alternate_url': 'https://hh.ru/vacancy/106773968',
#     'relations': [],
#     'employer': {'id': '5036807',
#      'name': 'ГК ВЫСОТА - СЕРВИС (ООО УК ВЫСОТА 4884. СЕРВИС)',
#      'url': 'https://api.hh.ru/employers/5036807',
#      'alternate_url': 'https://hh.ru/employer/5036807',
#      'logo_urls': {'original': 'https://img.hhcdn.ru/employer-logo-original/904560.jpg',
#       '90': 'https://img.hhcdn.ru/employer-logo/4058927.jpeg',
#       '240': 'https://img.hhcdn.ru/employer-logo/4058928.jpeg'},
#      'vacancies_url': 'https://api.hh.ru/vacancies?employer_id=5036807',
#      'accredited_it_employer': False,
#      'trusted': True},
#     'snippet': {'requirement': 'Образование: среднее профессиональное, высшее, курсы повышения квалификации. Опыт работы в сфере от 2 лет. Исполнительность. Работоспособность. Творческий подход.',
#      'responsibility': 'Проведение регулярных осмотров территории, мониторинга зеленых насаждений, выявление повреждений с оформлением соответствующей документации. Составление планов работ, формирование закупок. '},
#     'contacts': None,
#     'schedule': {'id': 'fullDay', 'name': 'Полный день'},
#     'working_days': [],
#     'working_time_intervals': [],
#     'working_time_modes': [],
#     'accept_temporary': True,
#     'professional_roles': [{'id': '7', 'name': 'Агроном'}],
#     'accept_incomplete_resumes': False,
#     'experience': {'id': 'between1And3', 'name': 'От 1 года до 3 лет'},
#     'employment': {'id': 'full', 'name': 'Полная занятость'},
#     'adv_response_url': None,
#     'is_adv_vacancy': False,
#     'adv_context': None},
#    {'id': '105834528',
#     'premium': False,
#     'name': 'Флорист-агроном в шоурум флорариумов',
#     'department': None,
#     'has_test': False,
#     'response_letter_required': False,
#     'area': {'id': '1', 'name': 'Москва', 'url': 'https://api.hh.ru/areas/1'},
#     'salary': {'from': 70000, 'to': 100000, 'currency': 'RUR', 'gross': False},
#     'type': {'id': 'open', 'name': 'Открытая'},
#     'address': {'city': 'Москва',
#      'street': 'Садовая-Кудринская улица',
#      'building': '20',
#      'lat': 55.762404,
#      'lng': 37.587973,
#      'description': None,
#      'raw': 'Москва, Садовая-Кудринская улица, 20',
#      'metro': {'station_name': 'Баррикадная',
#       'line_name': 'Таганско-Краснопресненская',
#       'station_id': '7.16',
#       'line_id': '7',
#       'lat': 55.760793,
#       'lng': 37.581242},
#      'metro_stations': [{'station_name': 'Баррикадная',
#        'line_name': 'Таганско-Краснопресненская',
#        'station_id': '7.16',
#        'line_id': '7',
#        'lat': 55.760793,
#        'lng': 37.581242},
#       {'station_name': 'Краснопресненская',
#        'line_name': 'Кольцевая',
#        'station_id': '5.58',
#        'line_id': '5',
#        'lat': 55.760378,
#        'lng': 37.577114},
#       {'station_name': 'Маяковская',
#        'line_name': 'Замоскворецкая',
#        'station_id': '2.80',
#        'line_id': '2',
#        'lat': 55.769808,
#        'lng': 37.596192},
#       {'station_name': 'Тверская',
#        'line_name': 'Замоскворецкая',
#        'station_id': '2.122',
#        'line_id': '2',
#        'lat': 55.765343,
#        'lng': 37.603918}],
#      'id': '16080943'},
#     'response_url': None,
#     'sort_point_distance': None,
#     'published_at': '2024-09-11T09:31:53+0300',
#     'created_at': '2024-09-11T09:31:53+0300',
#     'archived': False,
#     'apply_alternate_url': 'https://hh.ru/applicant/vacancy_response?vacancyId=105834528',
#     'show_logo_in_search': None,
#     'insider_interview': None,
#     'url': 'https://api.hh.ru/vacancies/105834528?host=hh.ru',
#     'alternate_url': 'https://hh.ru/vacancy/105834528',
#     'relations': [],
#     'employer': {'id': '5888368',
#      'name': 'NEOPURE',
#      'url': 'https://api.hh.ru/employers/5888368',
#      'alternate_url': 'https://hh.ru/employer/5888368',
#      'logo_urls': {'240': 'https://img.hhcdn.ru/employer-logo/6596082.jpeg',
#       '90': 'https://img.hhcdn.ru/employer-logo/6596081.jpeg',
#       'original': 'https://img.hhcdn.ru/employer-logo-original/1243912.jpg'},
#      'vacancies_url': 'https://api.hh.ru/vacancies?employer_id=5888368',
#      'accredited_it_employer': False,
#      'trusted': True},
#     'snippet': {'requirement': 'Знание ассортимента комнатных растений. Знание компонентов грунта. Знание основных вредителей и болезней, умение подобрать правильное лечение. Инициативность, ответственность, умение взять...',
#      'responsibility': 'Общение с посетителями шоурума. Сборка и отправка заказов. Сборка флорариумов. Работа с горшечными растениями. Ведение таблиц учёта. Поддержание порядка и...'},
#     'contacts': None,
#     'schedule': {'id': 'fullDay', 'name': 'Полный день'},
#     'working_days': [],
#     'working_time_intervals': [],
#     'working_time_modes': [],
#     'accept_temporary': False,
#     'professional_roles': [{'id': '40', 'name': 'Другое'}],
#     'accept_incomplete_resumes': True,
#     'experience': {'id': 'between1And3', 'name': 'От 1 года до 3 лет'},
#     'employment': {'id': 'full', 'name': 'Полная занятость'},
#     'adv_response_url': None,
#     'is_adv_vacancy': False,
#     'adv_context': None},
#    {'id': '106755789',
#     'premium': False,
#     'name': 'Менеджер по технологическому сопровождению/ Агроном-консультант',
#     'department': None,
#     'has_test': False,
#     'response_letter_required': False,
#     'area': {'id': '1', 'name': 'Москва', 'url': 'https://api.hh.ru/areas/1'},
#     'salary': None,
#     'type': {'id': 'open', 'name': 'Открытая'},
#     'address': None,
#     'response_url': None,
#     'sort_point_distance': None,
#     'published_at': '2024-09-10T10:14:11+0300',
#     'created_at': '2024-09-10T10:14:11+0300',
#     'archived': False,
#     'apply_alternate_url': 'https://hh.ru/applicant/vacancy_response?vacancyId=106755789',
#     'show_logo_in_search': None,
#     'insider_interview': None,
#     'url': 'https://api.hh.ru/vacancies/106755789?host=hh.ru',
#     'alternate_url': 'https://hh.ru/vacancy/106755789',
#     'relations': [],
#     'employer': {'id': '122438',
#      'name': 'Агрорус',
#      'url': 'https://api.hh.ru/employers/122438',
#      'alternate_url': 'https://hh.ru/employer/122438',
#      'logo_urls': {'original': 'https://img.hhcdn.ru/employer-logo-original/205425.JPG',
#       '90': 'https://img.hhcdn.ru/employer-logo/336465.jpeg',
#       '240': 'https://img.hhcdn.ru/employer-logo/409322.jpeg'},
#      'vacancies_url': 'https://api.hh.ru/vacancies?employer_id=122438',
#      'accredited_it_employer': False,
#      'trusted': True},
#     'snippet': {'requirement': 'Образование: высшее профессиональное образование (агрономия, защита растений, агрохимия и т.п.). Опыт работы в сельскохозяйственном производстве. Знание актуальных систем возделывания...',
#      'responsibility': 'Выезд в хозяйства на вверенной территории, закладка демонстрационных испытаний и производственных опытов по препаратам компании. Контроль внесения препаратов, отслеживание результатов...'},
#     'contacts': None,
#     'schedule': {'id': 'fullDay', 'name': 'Полный день'},
#     'working_days': [],
#     'working_time_intervals': [],
#     'working_time_modes': [],
#     'accept_temporary': False,
#     'professional_roles': [{'id': '7', 'name': 'Агроном'}],
#     'accept_incomplete_resumes': False,
#     'experience': {'id': 'between3And6', 'name': 'От 3 до 6 лет'},
#     'employment': {'id': 'full', 'name': 'Полная занятость'},
#     'adv_response_url': None,
#     'is_adv_vacancy': False,
#     'adv_context': None},
#    {'id': '106019565',
#     'premium': False,
#     'name': 'Агроном (садовник)',
#     'department': None,
#     'has_test': False,
#     'response_letter_required': False,
#     'area': {'id': '1', 'name': 'Москва', 'url': 'https://api.hh.ru/areas/1'},
#     'salary': {'from': 160000,
#      'to': 180000,
#      'currency': 'RUR',
#      'gross': False},
#     'type': {'id': 'open', 'name': 'Открытая'},
#     'address': {'city': 'Москва',
#      'street': 'Выборгская улица',
#      'building': '9Ас1',
#      'lat': 55.836438,
#      'lng': 37.499381,
#      'description': None,
#      'raw': 'Москва, Выборгская улица, 9Ас1',
#      'metro': None,
#      'metro_stations': [],
#      'id': '14299377'},
#     'response_url': None,
#     'sort_point_distance': None,
#     'published_at': '2024-08-19T17:55:15+0300',
#     'created_at': '2024-08-19T17:55:15+0300',
#     'archived': False,
#     'apply_alternate_url': 'https://hh.ru/applicant/vacancy_response?vacancyId=106019565',
#     'show_logo_in_search': None,
#     'insider_interview': None,
#     'url': 'https://api.hh.ru/vacancies/106019565?host=hh.ru',
#     'alternate_url': 'https://hh.ru/vacancy/106019565',
#     'relations': [],
#     'employer': {'id': '2302207',
#      'name': 'КРОСТ',
#      'url': 'https://api.hh.ru/employers/2302207',
#      'alternate_url': 'https://hh.ru/employer/2302207',
#      'logo_urls': {'240': 'https://img.hhcdn.ru/employer-logo/2806512.jpeg',
#       '90': 'https://img.hhcdn.ru/employer-logo/2806511.jpeg',
#       'original': 'https://img.hhcdn.ru/employer-logo-original/591314.jpg'},
#      'vacancies_url': 'https://api.hh.ru/vacancies?employer_id=2302207',
#      'accredited_it_employer': False,
#      'trusted': True},
#     'snippet': {'requirement': 'Высшее агрономическое образование (Тимирязевская СХ Академия, МГУЛ, др. СХ Вузы). Опыт работы от 3-х лет (опыт работы с крупных...',
#      'responsibility': 'Проведение дендрологических обследований зеленых насаждений. Подбор ассортимента посадочного материала для реализации проектных решений. Контроль при закупке посадочного материала и садовой...'},
#     'contacts': None,
#     'schedule': {'id': 'fullDay', 'name': 'Полный день'},
#     'working_days': [],
#     'working_time_intervals': [],
#     'working_time_modes': [],
#     'accept_temporary': False,
#     'professional_roles': [{'id': '7', 'name': 'Агроном'}],
#     'accept_incomplete_resumes': False,
#     'experience': {'id': 'between3And6', 'name': 'От 3 до 6 лет'},
#     'employment': {'id': 'full', 'name': 'Полная занятость'},
#     'adv_response_url': None,
#     'is_adv_vacancy': False,
#     'adv_context': None},
#    {'id': '106041540',
#     'premium': False,
#     'name': 'Производственный директор - Главный агроном (Растениеводство)',
#     'department': None,
#     'has_test': False,
#     'response_letter_required': False,
#     'area': {'id': '1', 'name': 'Москва', 'url': 'https://api.hh.ru/areas/1'},
#     'salary': {'from': 200000, 'to': 300000, 'currency': 'RUR', 'gross': True},
#     'type': {'id': 'open', 'name': 'Открытая'},
#     'address': {'city': 'Москва',
#      'street': None,
#      'building': None,
#      'lat': 55.685026,
#      'lng': 37.733904,
#      'description': None,
#      'raw': 'Москва',
#      'metro': None,
#      'metro_stations': [],
#      'id': '16102152'},
#     'response_url': None,
#     'sort_point_distance': None,
#     'published_at': '2024-08-20T10:23:03+0300',
#     'created_at': '2024-08-20T10:23:03+0300',
#     'archived': False,
#     'apply_alternate_url': 'https://hh.ru/applicant/vacancy_response?vacancyId=106041540',
#     'insider_interview': None,
#     'url': 'https://api.hh.ru/vacancies/106041540?host=hh.ru',
#     'alternate_url': 'https://hh.ru/vacancy/106041540',
#     'relations': [],
#     'employer': {'id': '1689259',
#      'name': 'ДЖЕЙКЕТ РАБОТА',
#      'url': 'https://api.hh.ru/employers/1689259',
#      'alternate_url': 'https://hh.ru/employer/1689259',
#      'logo_urls': None,
#      'vacancies_url': 'https://api.hh.ru/vacancies?employer_id=1689259',
#      'accredited_it_employer': False,
#      'trusted': True},
#     'snippet': {'requirement': 'Знающий и умеющий работать с агрономической документацией, а также со складской, производственной, упаковочной, отгрузочной документацией. Нацеленный не только на доскональное...',
#      'responsibility': 'Качество готовой продукции соответствует как внутренним стандартам качества, так и ГОСТам. Методы управления производственной очередью гарантируют исполнение сроков отгрузки готовой...'},
#     'contacts': None,
#     'schedule': {'id': 'fullDay', 'name': 'Полный день'},
#     'working_days': [],
#     'working_time_intervals': [],
#     'working_time_modes': [],
#     'accept_temporary': False,
#     'professional_roles': [{'id': '87',
#       'name': 'Операционный директор (COO)'}],
#     'accept_incomplete_resumes': True,
#     'experience': {'id': 'moreThan6', 'name': 'Более 6 лет'},
#     'employment': {'id': 'full', 'name': 'Полная занятость'},
#     'adv_response_url': None,
#     'is_adv_vacancy': False,
#     'adv_context': None},
#    {'id': '105991117',
#     'premium': False,
#     'name': 'Агроном-садовник',
#     'department': None,
#     'has_test': False,
#     'response_letter_required': False,
#     'area': {'id': '1', 'name': 'Москва', 'url': 'https://api.hh.ru/areas/1'},
#     'salary': {'from': 100000,
#      'to': 150000,
#      'currency': 'RUR',
#      'gross': False},
#     'type': {'id': 'open', 'name': 'Открытая'},
#     'address': {'city': 'Московский поселение',
#      'street': '22-й километр',
#      'building': '4стр1',
#      'lat': 55.634151,
#      'lng': 37.441026,
#      'description': None,
#      'raw': 'Московский поселение, 22-й километр, 4стр1',
#      'metro': {'station_name': 'Румянцево',
#       'line_name': 'Сокольническая',
#       'station_id': '1.513',
#       'line_id': '1',
#       'lat': 55.633,
#       'lng': 37.4419},
#      'metro_stations': [{'station_name': 'Румянцево',
#        'line_name': 'Сокольническая',
#        'station_id': '1.513',
#        'line_id': '1',
#        'lat': 55.633,
#        'lng': 37.4419}],
#      'id': '16417700'},
#     'response_url': None,
#     'sort_point_distance': None,
#     'published_at': '2024-09-12T12:30:19+0300',
#     'created_at': '2024-09-12T12:30:19+0300',
#     'archived': False,
#     'apply_alternate_url': 'https://hh.ru/applicant/vacancy_response?vacancyId=105991117',
#     'insider_interview': None,
#     'url': 'https://api.hh.ru/vacancies/105991117?host=hh.ru',
#     'alternate_url': 'https://hh.ru/vacancy/105991117',
#     'relations': [],
#     'employer': {'id': '1689259',
#      'name': 'ДЖЕЙКЕТ РАБОТА',
#      'url': 'https://api.hh.ru/employers/1689259',
#      'alternate_url': 'https://hh.ru/employer/1689259',
#      'logo_urls': None,
#      'vacancies_url': 'https://api.hh.ru/vacancies?employer_id=1689259',
#      'accredited_it_employer': False,
#      'trusted': True},
#     'snippet': {'requirement': 'Знание растений Подмосковья и способы ухода за ними. Образование - аграрный колледж или институт. Умение работать садовым инструментом. Аккуратность и трудолюбие. ',
#      'responsibility': 'Самостоятельный уход за растениями. Руководство бригадой рабочих для сервисного обслуживания зеленых насаждений на территории клиентов. Реализация проектов по благоустройству и...'},
#     'contacts': None,
#     'schedule': {'id': 'flexible', 'name': 'Гибкий график'},
#     'working_days': [],
#     'working_time_intervals': [],
#     'working_time_modes': [],
#     'accept_temporary': False,
#     'professional_roles': [{'id': '7', 'name': 'Агроном'}],
#     'accept_incomplete_resumes': True,
#     'experience': {'id': 'between1And3', 'name': 'От 1 года до 3 лет'},
#     'employment': {'id': 'full', 'name': 'Полная занятость'},
#     'adv_response_url': None,
#     'is_adv_vacancy': False,
#     'adv_context': None},
#    {'id': '105045436',
#     'premium': False,
#     'name': 'Агроном',
#     'department': None,
#     'has_test': False,
#     'response_letter_required': False,
#     'area': {'id': '1', 'name': 'Москва', 'url': 'https://api.hh.ru/areas/1'},
#     'salary': {'from': None, 'to': 80000, 'currency': 'RUR', 'gross': False},
#     'type': {'id': 'open', 'name': 'Открытая'},
#     'address': {'city': 'Москва',
#      'street': 'Рябиновая улица',
#      'building': '44с28',
#      'lat': 55.673306,
#      'lng': 37.432115,
#      'description': None,
#      'raw': 'Москва, Рябиновая улица, 44с28',
#      'metro': {'station_name': 'Говорово',
#       'line_name': 'Солнцевская',
#       'station_id': '133.609',
#       'line_id': '133',
#       'lat': 55.6588,
#       'lng': 37.4174},
#      'metro_stations': [{'station_name': 'Говорово',
#        'line_name': 'Солнцевская',
#        'station_id': '133.609',
#        'line_id': '133',
#        'lat': 55.6588,
#        'lng': 37.4174},
#       {'station_name': 'Озёрная',
#        'line_name': 'Солнцевская',
#        'station_id': '133.608',
#        'line_id': '133',
#        'lat': 55.6698,
#        'lng': 37.4495},
#       {'station_name': 'Сколково',
#        'line_name': 'МЦД-1',
#        'station_id': '131.708',
#        'line_id': '131',
#        'lat': 55.666801,
#        'lng': 37.424618}],
#      'id': '5597783'},
#     'response_url': None,
#     'sort_point_distance': None,
#     'published_at': '2024-08-22T08:56:51+0300',
#     'created_at': '2024-08-22T08:56:51+0300',
#     'archived': False,
#     'apply_alternate_url': 'https://hh.ru/applicant/vacancy_response?vacancyId=105045436',
#     'show_logo_in_search': None,
#     'insider_interview': None,
#     'url': 'https://api.hh.ru/vacancies/105045436?host=hh.ru',
#     'alternate_url': 'https://hh.ru/vacancy/105045436',
#     'relations': [],
#     'employer': {'id': '2756417',
#      'name': 'МИЛТИ',
#      'url': 'https://api.hh.ru/employers/2756417',
#      'alternate_url': 'https://hh.ru/employer/2756417',
#      'logo_urls': {'240': 'https://img.hhcdn.ru/employer-logo/3733484.jpeg',
#       '90': 'https://img.hhcdn.ru/employer-logo/3733483.jpeg',
#       'original': 'https://img.hhcdn.ru/employer-logo-original/823149.JPG'},
# ...
#     'accept_incomplete_resumes': False,
#     'experience': {'id': 'between1And3', 'name': 'От 1 года до 3 лет'},
#     'employment': {'id': 'full', 'name': 'Полная занятость'},
#     'adv_response_url': None,
#     'is_adv_vacancy': False,
#     'adv_context': None},
#    {'id': '105924903',
#     'premium': False,
#     'name': 'Выездной агроном на объекты клиентов',
#     'department': None,
#     'has_test': False,
#     'response_letter_required': False,
#     'area': {'id': '1', 'name': 'Москва', 'url': 'https://api.hh.ru/areas/1'},
#     'salary': {'from': 70000, 'to': 120000, 'currency': 'RUR', 'gross': False},
#     'type': {'id': 'open', 'name': 'Открытая'},
#     'address': {'city': 'село Ильинское',
#      'street': 'Экспериментальная улица',
#      'building': '14',
#      'lat': 55.762115,
#      'lng': 37.229132,
#      'description': None,
#      'raw': 'село Ильинское, Экспериментальная улица, 14',
#      'metro': None,
#      'metro_stations': [],
#      'id': '15001429'},
#     'response_url': None,
#     'sort_point_distance': None,
#     'published_at': '2024-08-16T15:18:04+0300',
#     'created_at': '2024-08-16T15:18:04+0300',
#     'archived': False,
#     'apply_alternate_url': 'https://hh.ru/applicant/vacancy_response?vacancyId=105924903',
#     'show_logo_in_search': None,
#     'insider_interview': None,
#     'url': 'https://api.hh.ru/vacancies/105924903?host=hh.ru',
#     'alternate_url': 'https://hh.ru/vacancy/105924903',
#     'relations': [],
#     'employer': {'id': '4438089',
#      'name': 'ЭкоПлантТ',
#      'url': 'https://api.hh.ru/employers/4438089',
#      'alternate_url': 'https://hh.ru/employer/4438089',
#      'logo_urls': {'90': 'https://img.hhcdn.ru/employer-logo/6764678.jpeg',
#       'original': 'https://img.hhcdn.ru/employer-logo-original/1286095.jpeg',
#       '240': 'https://img.hhcdn.ru/employer-logo/6764679.jpeg'},
#      'vacancies_url': 'https://api.hh.ru/vacancies?employer_id=4438089',
#      'accredited_it_employer': False,
#      'trusted': True},
#     'snippet': {'requirement': 'Опыт работы агрономом или садовником. Также рассматриваем выпускников по специальностям связанным с агрономией, без опыта работы. Всесторонние знания в области...',
#      'responsibility': 'Забирать из питомника рабочих (2-3 человека). Выезжать на объекты клиентов (5-6 объектов за день, все рядом территориально). '},
#     'contacts': None,
#     'schedule': {'id': 'fullDay', 'name': 'Полный день'},
#     'working_days': [],
#     'working_time_intervals': [],
#     'working_time_modes': [],
#     'accept_temporary': True,
#     'professional_roles': [{'id': '7', 'name': 'Агроном'}],
#     'accept_incomplete_resumes': False,
#     'experience': {'id': 'between1And3', 'name': 'От 1 года до 3 лет'},
#     'employment': {'id': 'full', 'name': 'Полная занятость'},
#     'adv_response_url': None,
#     'is_adv_vacancy': False,
#     'adv_context': None},
#    {'id': '106661028',
#     'premium': False,
#     'name': 'Агроном',
#     'department': None,
#     'has_test': False,
#     'response_letter_required': False,
#     'area': {'id': '1', 'name': 'Москва', 'url': 'https://api.hh.ru/areas/1'},
#     'salary': None,
#     'type': {'id': 'open', 'name': 'Открытая'},
#     'address': None,
#     'response_url': None,
#     'sort_point_distance': None,
#     'published_at': '2024-09-02T15:40:14+0300',
#     'created_at': '2024-09-02T15:40:14+0300',
#     'archived': False,
#     'apply_alternate_url': 'https://hh.ru/applicant/vacancy_response?vacancyId=106661028',
#     'show_logo_in_search': None,
#     'insider_interview': None,
#     'url': 'https://api.hh.ru/vacancies/106661028?host=hh.ru',
#     'alternate_url': 'https://hh.ru/vacancy/106661028',
#     'relations': [],
#     'employer': {'id': '1124',
#      'name': 'Fersol',
#      'url': 'https://api.hh.ru/employers/1124',
#      'alternate_url': 'https://hh.ru/employer/1124',
#      'logo_urls': {'original': 'https://img.hhcdn.ru/employer-logo-original/1002135.jpg',
#       '90': 'https://img.hhcdn.ru/employer-logo/5629320.jpeg',
#       '240': 'https://img.hhcdn.ru/employer-logo/5629321.jpeg'},
#      'vacancies_url': 'https://api.hh.ru/vacancies?employer_id=1124',
#      'accredited_it_employer': False,
#      'trusted': True},
#     'snippet': {'requirement': 'Высшее образование по направлению Агрономия. Знание и понимание технологий возделывания основных с\\х культур. Знание и понимание биологии развития растений...',
#      'responsibility': 'Проведение сопоставлений полимерных решений для систем формирования условий выращивания культуры. Анализ и выбор свойств решения для определённой культуры. '},
#     'contacts': None,
#     'schedule': {'id': 'fullDay', 'name': 'Полный день'},
#     'working_days': [],
#     'working_time_intervals': [],
#     'working_time_modes': [],
#     'accept_temporary': False,
#     'professional_roles': [{'id': '7', 'name': 'Агроном'}],
#     'accept_incomplete_resumes': False,
#     'experience': {'id': 'moreThan6', 'name': 'Более 6 лет'},
#     'employment': {'id': 'full', 'name': 'Полная занятость'},
#     'adv_response_url': None,
#     'is_adv_vacancy': False,
#     'adv_context': None},
#    {'id': '102197513',
#     'premium': False,
#     'name': 'Главный агроном',
#     'department': None,
#     'has_test': False,
#     'response_letter_required': False,
#     'area': {'id': '1', 'name': 'Москва', 'url': 'https://api.hh.ru/areas/1'},
#     'salary': None,
#     'type': {'id': 'open', 'name': 'Открытая'},
#     'address': {'city': None,
#      'street': None,
#      'building': None,
#      'lat': 45.03540698031786,
#      'lng': 38.97527692839503,
#      'description': None,
#      'raw': 'г. Краснодар улица Солнечная 15/5',
#      'metro': None,
#      'metro_stations': [],
#      'id': '228786'},
#     'response_url': None,
#     'sort_point_distance': None,
#     'published_at': '2024-09-02T09:26:14+0300',
#     'created_at': '2024-09-02T09:26:14+0300',
#     'archived': False,
#     'apply_alternate_url': 'https://hh.ru/applicant/vacancy_response?vacancyId=102197513',
#     'branding': {'type': 'MAKEUP', 'tariff': None},
#     'show_logo_in_search': True,
#     'insider_interview': None,
#     'url': 'https://api.hh.ru/vacancies/102197513?host=hh.ru',
#     'alternate_url': 'https://hh.ru/vacancy/102197513',
#     'relations': [],
#     'employer': {'id': '49357',
#      'name': 'МАГНИТ, Розничная сеть',
#      'url': 'https://api.hh.ru/employers/49357',
#      'alternate_url': 'https://hh.ru/employer/49357',
#      'logo_urls': {'original': 'https://img.hhcdn.ru/employer-logo-original/1261115.jpg',
#       '90': 'https://img.hhcdn.ru/employer-logo/6664786.jpeg',
#       '240': 'https://img.hhcdn.ru/employer-logo/6664787.jpeg'},
#      'vacancies_url': 'https://api.hh.ru/vacancies?employer_id=49357',
#      'accredited_it_employer': False,
#      'trusted': True},
#     'snippet': {'requirement': 'Высшее образование (<highlighttext>агроном</highlighttext>). Опыт работы в должности Главного агронома, Директора по производству, Операционного директора на производстве в крупных холдингах по...',
#      'responsibility': 'Анализ агротехнических и грибоводческих решений агрономов ЗЛ, МнД и ГрК в ходе управления выращиванием продукции. Выработка регламентов выращивания, защиты, формирование...'},
#     'contacts': None,
#     'schedule': {'id': 'fullDay', 'name': 'Полный день'},
#     'working_days': [],
#     'working_time_intervals': [],
#     'working_time_modes': [],
#     'accept_temporary': False,
#     'professional_roles': [{'id': '7', 'name': 'Агроном'}],
#     'accept_incomplete_resumes': False,
#     'experience': {'id': 'between3And6', 'name': 'От 3 до 6 лет'},
#     'employment': {'id': 'full', 'name': 'Полная занятость'},
#     'adv_response_url': None,
#     'is_adv_vacancy': False,
#     'adv_context': None},
#    {'id': '105990501',
#     'premium': False,
#     'name': 'Агроном-садовник',
#     'department': None,
#     'has_test': False,
#     'response_letter_required': False,
#     'area': {'id': '1', 'name': 'Москва', 'url': 'https://api.hh.ru/areas/1'},
#     'salary': {'from': 100000,
#      'to': 150000,
#      'currency': 'RUR',
#      'gross': False},
#     'type': {'id': 'open', 'name': 'Открытая'},
#     'address': {'city': 'Москва',
#      'street': 'Киевское шоссе 22-й (п Московский) километр',
#      'building': '4стр1',
#      'lat': 55.634151,
#      'lng': 37.441026,
#      'description': None,
#      'raw': 'Москва, Киевское шоссе 22-й (п Московский) километр, 4стр1',
#      'metro': {'station_name': 'Румянцево',
#       'line_name': 'Сокольническая',
#       'station_id': '1.513',
#       'line_id': '1',
#       'lat': 55.633,
#       'lng': 37.4419},
#      'metro_stations': [{'station_name': 'Румянцево',
#        'line_name': 'Сокольническая',
#        'station_id': '1.513',
#        'line_id': '1',
#        'lat': 55.633,
#        'lng': 37.4419}],
#      'id': '5648157'},
#     'response_url': None,
#     'sort_point_distance': None,
#     'published_at': '2024-09-12T12:24:37+0300',
#     'created_at': '2024-09-12T12:24:37+0300',
#     'archived': False,
#     'apply_alternate_url': 'https://hh.ru/applicant/vacancy_response?vacancyId=105990501',
#     'insider_interview': None,
#     'url': 'https://api.hh.ru/vacancies/105990501?host=hh.ru',
#     'alternate_url': 'https://hh.ru/vacancy/105990501',
#     'relations': [],
#     'employer': {'id': '1689259',
#      'name': 'ДЖЕЙКЕТ РАБОТА',
#      'url': 'https://api.hh.ru/employers/1689259',
#      'alternate_url': 'https://hh.ru/employer/1689259',
#      'logo_urls': None,
#      'vacancies_url': 'https://api.hh.ru/vacancies?employer_id=1689259',
#      'accredited_it_employer': False,
#      'trusted': True},
#     'snippet': {'requirement': 'Знание растений Подмосковья и способы ухода за ними. Образование - аграрный колледж или институт. Умение работать садовым инструментом. Аккуратность и трудолюбие. ',
#      'responsibility': 'Самостоятельный уход за растениями. Руководство бригадой рабочих для сервисного обслуживания зеленых насаждений на территории клиентов. Реализация проектов по благоустройству и...'},
#     'contacts': None,
#     'schedule': {'id': 'flexible', 'name': 'Гибкий график'},
#     'working_days': [],
#     'working_time_intervals': [],
#     'working_time_modes': [],
#     'accept_temporary': False,
#     'professional_roles': [{'id': '7', 'name': 'Агроном'}],
#     'accept_incomplete_resumes': True,
#     'experience': {'id': 'between1And3', 'name': 'От 1 года до 3 лет'},
#     'employment': {'id': 'full', 'name': 'Полная занятость'},
#     'adv_response_url': None,
#     'is_adv_vacancy': False,
#     'adv_context': None}],
#   [{'id': '106238837',
#     'premium': False,
#     'name': 'Главный инженер проекта',
#     'department': None,
#     'has_test': False,
#     'response_letter_required': False,
#     'area': {'id': '1', 'name': 'Москва', 'url': 'https://api.hh.ru/areas/1'},
#     'salary': {'from': None, 'to': 200000, 'currency': 'RUR', 'gross': True},
#     'type': {'id': 'open', 'name': 'Открытая'},
#     'address': {'city': 'Москва',
#      'street': 'улица Радио',
#      'building': '23/9с1',
#      'lat': 55.763017,
#      'lng': 37.683356,
#      'description': None,
#      'raw': 'Москва, улица Радио, 23/9с1',
#      'metro': {'station_name': 'Лефортово',
#       'line_name': 'Большая кольцевая линия',
#       'station_id': '97.825',
#       'line_id': '97',
#       'lat': 55.764444,
#       'lng': 37.702778},
#      'metro_stations': [{'station_name': 'Лефортово',
#        'line_name': 'Большая кольцевая линия',
#        'station_id': '97.825',
#        'line_id': '97',
#        'lat': 55.764444,
#        'lng': 37.702778}],
#      'id': '14958977'},
#     'response_url': None,
#     'sort_point_distance': None,
#     'published_at': '2024-08-23T10:13:05+0300',
#     'created_at': '2024-08-23T10:13:05+0300',
#     'archived': False,
#     'apply_alternate_url': 'https://hh.ru/applicant/vacancy_response?vacancyId=106238837',
#     'show_logo_in_search': None,
#     'insider_interview': None,
#     'url': 'https://api.hh.ru/vacancies/106238837?host=hh.ru',
#     'alternate_url': 'https://hh.ru/vacancy/106238837',
#     'relations': [],
#     'employer': {'id': '10703368',
#      'name': 'Орка Проект',
#      'url': 'https://api.hh.ru/employers/10703368',
#      'alternate_url': 'https://hh.ru/employer/10703368',
#      'logo_urls': {'90': 'https://img.hhcdn.ru/employer-logo/6498641.png',
#       '240': 'https://img.hhcdn.ru/employer-logo/6498642.png',
#       'original': 'https://img.hhcdn.ru/employer-logo-original/1219550.png'},
#      'vacancies_url': 'https://api.hh.ru/vacancies?employer_id=10703368',
#      'accredited_it_employer': False,
#      'trusted': True},
#     'snippet': {'requirement': 'Высшее техническое образование (проектирование, архитектура). Опыт работы не менее 5-ти лет. Опыт работы проектировщиком. Опыт согласования документации с Москомархитектурой...',
#      'responsibility': 'Подготовка технических заданий и заданий на проектирование. Взаимоувязка проектных решений разделов АР, КР и инженерных систем. Организация работы смежных разделов...'},
#     'contacts': None,
#     'schedule': {'id': 'fullDay', 'name': 'Полный день'},
#     'working_days': [],
#     'working_time_intervals': [],
#     'working_time_modes': [],
#     'accept_temporary': False,
#     'professional_roles': [{'id': '30', 'name': 'Главный инженер проекта'}],
#     'accept_incomplete_resumes': False,
#     'experience': {'id': 'moreThan6', 'name': 'Более 6 лет'},
#     'employment': {'id': 'full', 'name': 'Полная занятость'},
#     'adv_response_url': None,
#     'is_adv_vacancy': False,
#     'adv_context': None},
#    {'id': '105721839',
#     'premium': False,
#     'name': 'Агроном',
#     'department': None,
#     'has_test': False,
#     'response_letter_required': False,
#     'area': {'id': '1', 'name': 'Москва', 'url': 'https://api.hh.ru/areas/1'},
#     'salary': {'from': 60000, 'to': 80000, 'currency': 'RUR', 'gross': True},
#     'type': {'id': 'open', 'name': 'Открытая'},
#     'address': {'city': 'Москва',
#      'street': None,
#      'building': 'парк Ходынское поле',
#      'lat': 55.786743,
#      'lng': 37.53031,
#      'description': None,
#      'raw': 'Москва, парк Ходынское поле',
#      'metro': None,
#      'metro_stations': [],
#      'id': '13158341'},
#     'response_url': None,
#     'sort_point_distance': None,
#     'published_at': '2024-09-12T09:06:00+0300',
#     'created_at': '2024-09-12T09:06:00+0300',
#     'archived': False,
#     'apply_alternate_url': 'https://hh.ru/applicant/vacancy_response?vacancyId=105721839',
#     'show_logo_in_search': None,
#     'insider_interview': None,
#     'url': 'https://api.hh.ru/vacancies/105721839?host=hh.ru',
#     'alternate_url': 'https://hh.ru/vacancy/105721839',
#     'relations': [],
#     'employer': {'id': '1617659',
#      'name': 'ГАУК Парк культуры и отдыха Ходынское поле',
#      'url': 'https://api.hh.ru/employers/1617659',
#      'alternate_url': 'https://hh.ru/employer/1617659',
#      'logo_urls': {'240': 'https://img.hhcdn.ru/employer-logo/5501925.jpeg',
#       '90': 'https://img.hhcdn.ru/employer-logo/5501924.jpeg',
#       'original': 'https://img.hhcdn.ru/employer-logo-original/970279.jpeg'},
#      'vacancies_url': 'https://api.hh.ru/vacancies?employer_id=1617659',
#      'accredited_it_employer': False,
#      'trusted': True},
#     'snippet': {'requirement': 'высшее профессиональное образование. Должен знать: Агротехнические особенности декоративных растений. Основы дендрологии, ботаники, почвоведения, декоративного садоводства. Экологические, социально-экономические, агротехнические, технические...',
#      'responsibility': 'Осуществляет эскизные зарисовки, фотографирование объектов проектирования, наиболее характерных пейзажей, памятников истории и культуры. Разрабатывает ландшафтно-планировочные решения по конкретным разделам...'},
#     'contacts': None,
#     'schedule': {'id': 'fullDay', 'name': 'Полный день'},
#     'working_days': [],
#     'working_time_intervals': [],
#     'working_time_modes': [],
#     'accept_temporary': False,
#     'professional_roles': [{'id': '7', 'name': 'Агроном'}],
#     'accept_incomplete_resumes': False,
#     'experience': {'id': 'between3And6', 'name': 'От 3 до 6 лет'},
#     'employment': {'id': 'full', 'name': 'Полная занятость'},
#     'adv_response_url': None,
#     'is_adv_vacancy': False,
#     'adv_context': None}]],
#  'found': 52}

# %%
test = get_vacancies(vacancy_name='Агроном')

# %%
test
# Out:
# {'items': [{'id': '107214681',
#    'premium': False,
#    'name': 'Главный агроном',
#    'department': None,
#    'has_test': False,
#    'response_letter_required': False,
#    'area': {'id': '1', 'name': 'Москва', 'url': 'https://api.hh.ru/areas/1'},
#    'salary': {'from': 180000, 'to': None, 'currency': 'RUR', 'gross': False},
#    'type': {'id': 'open', 'name': 'Открытая'},
#    'address': None,
#    'response_url': None,
#    'sort_point_distance': None,
#    'published_at': '2024-09-12T17:36:02+0300',
#    'created_at': '2024-09-12T17:36:02+0300',
#    'archived': False,
#    'apply_alternate_url': 'https://hh.ru/applicant/vacancy_response?vacancyId=107214681',
#    'show_logo_in_search': None,
#    'insider_interview': None,
#    'url': 'https://api.hh.ru/vacancies/107214681?host=hh.ru',
#    'alternate_url': 'https://hh.ru/vacancy/107214681',
#    'relations': [],
#    'employer': {'id': '1069209',
#     'name': 'Кадровый центр Президент',
#     'url': 'https://api.hh.ru/employers/1069209',
#     'alternate_url': 'https://hh.ru/employer/1069209',
#     'logo_urls': {'90': 'https://img.hhcdn.ru/employer-logo/6501065.jpeg',
#      '240': 'https://img.hhcdn.ru/employer-logo/6501066.jpeg',
#      'original': 'https://img.hhcdn.ru/employer-logo-original/1220156.jpg'},
#     'vacancies_url': 'https://api.hh.ru/vacancies?employer_id=1069209',
#     'accredited_it_employer': False,
#     'trusted': True},
#    'snippet': {'requirement': 'Высшее профильное образование. Знание декоративных растений и их агротехники. Наличие управленческого опыта. Навыки в сфере ландшафтно /паркового озеленения от 3...',
#     'responsibility': 'Организация работы всех структурных подразделений питомника. Планирование и организация производственного процесса по выращиванию и уходу за растениями. Составление отчётности, ведение...'},
#    'contacts': None,
#    'schedule': {'id': 'fullDay', 'name': 'Полный день'},
#    'working_days': [],
#    'working_time_intervals': [],
#    'working_time_modes': [],
#    'accept_temporary': False,
#    'professional_roles': [{'id': '7', 'name': 'Агроном'}],
#    'accept_incomplete_resumes': False,
#    'experience': {'id': 'between3And6', 'name': 'От 3 до 6 лет'},
#    'employment': {'id': 'full', 'name': 'Полная занятость'},
#    'adv_response_url': None,
#    'is_adv_vacancy': False,
#    'adv_context': None},
#   {'id': '106335339',
#    'premium': False,
#    'name': 'Управляющий агрофермой (Агроном) релокация на Бали',
#    'department': None,
#    'has_test': False,
#    'response_letter_required': True,
#    'area': {'id': '1', 'name': 'Москва', 'url': 'https://api.hh.ru/areas/1'},
#    'salary': {'from': 2000, 'to': None, 'currency': 'USD', 'gross': True},
#    'type': {'id': 'open', 'name': 'Открытая'},
#    'address': None,
#    'response_url': None,
#    'sort_point_distance': None,
#    'published_at': '2024-08-26T14:39:27+0300',
#    'created_at': '2024-08-26T14:39:27+0300',
#    'archived': False,
#    'apply_alternate_url': 'https://hh.ru/applicant/vacancy_response?vacancyId=106335339',
#    'show_logo_in_search': None,
#    'insider_interview': None,
#    'url': 'https://api.hh.ru/vacancies/106335339?host=hh.ru',
#    'alternate_url': 'https://hh.ru/vacancy/106335339',
#    'relations': [],
#    'employer': {'id': '11217206',
#     'name': 'Всё, я увольняюсь!',
#     'url': 'https://api.hh.ru/employers/11217206',
#     'alternate_url': 'https://hh.ru/employer/11217206',
#     'logo_urls': {'240': 'https://img.hhcdn.ru/employer-logo/6932655.jpeg',
#      'original': 'https://img.hhcdn.ru/employer-logo-original/1328158.jpeg',
#      '90': 'https://img.hhcdn.ru/employer-logo/6932654.jpeg'},
#     'vacancies_url': 'https://api.hh.ru/vacancies?employer_id=11217206',
#     'accredited_it_employer': False,
#     'trusted': True},
#    'snippet': {'requirement': 'Профильное образование. Релевантный опыт работы. Не только разбираться, но и любить свою профессию.',
#     'responsibility': 'Контроль расходов и доходов, быстрая реакция на изменения и решение проблем. Настройка и регулировка параметров парников (влажность, температура, борьба с...'},
#    'contacts': None,
#    'schedule': {'id': 'fullDay', 'name': 'Полный день'},
#    'working_days': [],
#    'working_time_intervals': [],
#    'working_time_modes': [],
#    'accept_temporary': False,
#    'professional_roles': [{'id': '7', 'name': 'Агроном'}],
#    'accept_incomplete_resumes': False,
#    'experience': {'id': 'between3And6', 'name': 'От 3 до 6 лет'},
#    'employment': {'id': 'full', 'name': 'Полная занятость'},
#    'adv_response_url': None,
#    'is_adv_vacancy': False,
#    'adv_context': None},
#   {'id': '106435824',
#    'premium': False,
#    'name': 'Ландшафтный дизайнер/Садовник/Дендролог/Агроном',
#    'department': None,
#    'has_test': False,
#    'response_letter_required': False,
#    'area': {'id': '1', 'name': 'Москва', 'url': 'https://api.hh.ru/areas/1'},
#    'salary': {'from': 180000, 'to': None, 'currency': 'RUR', 'gross': False},
#    'type': {'id': 'open', 'name': 'Открытая'},
#    'address': None,
#    'response_url': None,
#    'sort_point_distance': None,
#    'published_at': '2024-09-02T10:32:17+0300',
#    'created_at': '2024-09-02T10:32:17+0300',
#    'archived': False,
#    'apply_alternate_url': 'https://hh.ru/applicant/vacancy_response?vacancyId=106435824',
#    'show_logo_in_search': None,
#    'insider_interview': None,
#    'url': 'https://api.hh.ru/vacancies/106435824?host=hh.ru',
#    'alternate_url': 'https://hh.ru/vacancy/106435824',
#    'relations': [],
#    'employer': {'id': '56479',
#     'name': 'Дэстэн Партнерс',
#     'url': 'https://api.hh.ru/employers/56479',
#     'alternate_url': 'https://hh.ru/employer/56479',
#     'logo_urls': {'240': 'https://img.hhcdn.ru/employer-logo/6825003.jpeg',
#      '90': 'https://img.hhcdn.ru/employer-logo/6825002.jpeg',
#      'original': 'https://img.hhcdn.ru/employer-logo-original/1301185.jpg'},
#     'vacancies_url': 'https://api.hh.ru/vacancies?employer_id=56479',
#     'accredited_it_employer': False,
#     'trusted': True},
#    'snippet': {'requirement': 'Опыт работы в смежной должности.',
#     'responsibility': 'Выезды к клиентам. 2-3 выезда в день (50-70 км от МКАДа). Анализ участка. Описывать фронт работы.'},
#    'contacts': None,
#    'schedule': {'id': 'fullDay', 'name': 'Полный день'},
#    'working_days': [],
#    'working_time_intervals': [],
#    'working_time_modes': [],
#    'accept_temporary': False,
#    'professional_roles': [{'id': '34', 'name': 'Дизайнер, художник'}],
#    'accept_incomplete_resumes': False,
#    'experience': {'id': 'between1And3', 'name': 'От 1 года до 3 лет'},
#    'employment': {'id': 'full', 'name': 'Полная занятость'},
#    'adv_response_url': None,
#    'is_adv_vacancy': False,
#    'adv_context': None},
#   {'id': '106918725',
#    'premium': False,
#    'name': 'Агроном',
#    'department': None,
#    'has_test': False,
#    'response_letter_required': False,
#    'area': {'id': '1', 'name': 'Москва', 'url': 'https://api.hh.ru/areas/1'},
#    'salary': {'from': 30000, 'to': 40000, 'currency': 'RUR', 'gross': False},
#    'type': {'id': 'open', 'name': 'Открытая'},
#    'address': {'city': 'Москва',
#     'street': 'улица Плеханова',
#     'building': '10',
#     'lat': 55.750226,
#     'lng': 37.760045,
#     'description': None,
#     'raw': 'Москва, улица Плеханова, 10',
#     'metro': {'station_name': 'Перово',
#      'line_name': 'Калининская',
#      'station_id': '8.107',
#      'line_id': '8',
#      'lat': 55.75098,
#      'lng': 37.78422},
#     'metro_stations': [{'station_name': 'Перово',
#       'line_name': 'Калининская',
#       'station_id': '8.107',
#       'line_id': '8',
#       'lat': 55.75098,
#       'lng': 37.78422}],
#     'id': '16486141'},
#    'response_url': None,
#    'sort_point_distance': None,
#    'published_at': '2024-09-06T16:36:22+0300',
#    'created_at': '2024-09-06T16:36:22+0300',
#    'archived': False,
#    'apply_alternate_url': 'https://hh.ru/applicant/vacancy_response?vacancyId=106918725',
#    'show_logo_in_search': None,
#    'insider_interview': None,
#    'url': 'https://api.hh.ru/vacancies/106918725?host=hh.ru',
#    'alternate_url': 'https://hh.ru/vacancy/106918725',
#    'relations': [],
#    'employer': {'id': '11412752',
#     'name': 'Здоровый Сад',
#     'url': 'https://api.hh.ru/employers/11412752',
#     'alternate_url': 'https://hh.ru/employer/11412752',
#     'logo_urls': {'original': 'https://img.hhcdn.ru/employer-logo-original/1328952.png',
#      '90': 'https://img.hhcdn.ru/employer-logo/6935826.png',
#      '240': 'https://img.hhcdn.ru/employer-logo/6935827.png'},
#     'vacancies_url': 'https://api.hh.ru/vacancies?employer_id=11412752',
#     'accredited_it_employer': False,
#     'trusted': True},
#    'snippet': {'requirement': 'Ответственность. Кропотливость. Внимательность. Способность брать на себя дополнительную работу (при необходимости) за отдельную плату - (например настроить стеллаж, подключить лампы, сделать...',
#     'responsibility': 'Выращивание таких культур как : микрозелень, бейби зелень, пищевые цветы, пряные травы. Знания в растениеводстве. Поддержание микроклимата в помещении. '},
#    'contacts': None,
#    'schedule': {'id': 'fullDay', 'name': 'Полный день'},
#    'working_days': [],
#    'working_time_intervals': [],
#    'working_time_modes': [],
#    'accept_temporary': True,
#    'professional_roles': [{'id': '7', 'name': 'Агроном'}],
#    'accept_incomplete_resumes': False,
#    'experience': {'id': 'between1And3', 'name': 'От 1 года до 3 лет'},
#    'employment': {'id': 'part', 'name': 'Частичная занятость'},
#    'adv_response_url': None,
#    'is_adv_vacancy': False,
#    'adv_context': None},
#   {'id': '105672373',
#    'premium': False,
#    'name': 'Агроном/овощевод',
#    'department': None,
#    'has_test': False,
#    'response_letter_required': False,
#    'area': {'id': '1', 'name': 'Москва', 'url': 'https://api.hh.ru/areas/1'},
#    'salary': {'from': 120000, 'to': None, 'currency': 'RUR', 'gross': False},
#    'type': {'id': 'open', 'name': 'Открытая'},
#    'address': None,
#    'response_url': None,
#    'sort_point_distance': None,
#    'published_at': '2024-08-28T12:27:02+0300',
#    'created_at': '2024-08-28T12:27:02+0300',
#    'archived': False,
#    'apply_alternate_url': 'https://hh.ru/applicant/vacancy_response?vacancyId=105672373',
#    'show_logo_in_search': None,
#    'insider_interview': None,
#    'url': 'https://api.hh.ru/vacancies/105672373?host=hh.ru',
#    'alternate_url': 'https://hh.ru/vacancy/105672373',
#    'relations': [],
#    'employer': {'id': '2161246',
#     'name': 'МОСМАКС ТРЕТЬЯКОВСКИЙ',
#     'url': 'https://api.hh.ru/employers/2161246',
#     'alternate_url': 'https://hh.ru/employer/2161246',
#     'logo_urls': {'240': 'https://img.hhcdn.ru/employer-logo/4088820.png',
#      '90': 'https://img.hhcdn.ru/employer-logo/4088819.png',
#      'original': 'https://img.hhcdn.ru/employer-logo-original/912033.png'},
#     'vacancies_url': 'https://api.hh.ru/vacancies?employer_id=2161246',
#     'accredited_it_employer': False,
#     'trusted': True},
#    'snippet': {'requirement': 'Честность, добросовестность, навыки и опыт работы в сельском хозяйстве.',
#     'responsibility': 'Работа в закрытом и открытом грунте. Посадка овощных культур и уход за ними (помидоры, огурцы).'},
#    'contacts': None,
#    'schedule': {'id': 'fullDay', 'name': 'Полный день'},
#    'working_days': [],
#    'working_time_intervals': [],
#    'working_time_modes': [],
#    'accept_temporary': False,
#    'professional_roles': [{'id': '7', 'name': 'Агроном'}],
#    'accept_incomplete_resumes': True,
#    'experience': {'id': 'between1And3', 'name': 'От 1 года до 3 лет'},
#    'employment': {'id': 'full', 'name': 'Полная занятость'},
#    'adv_response_url': None,
#    'is_adv_vacancy': False,
#    'adv_context': None},
#   {'id': '106066250',
#    'premium': False,
#    'name': 'Биолог/специалист по уходу за горшечными растениями',
#    'department': None,
#    'has_test': False,
#    'response_letter_required': False,
#    'area': {'id': '1', 'name': 'Москва', 'url': 'https://api.hh.ru/areas/1'},
#    'salary': {'from': 35000, 'to': 68000, 'currency': 'RUR', 'gross': False},
#    'type': {'id': 'open', 'name': 'Открытая'},
#    'address': {'city': 'деревня Аносино',
#     'street': 'Университетская улица',
#     'building': 'вл11',
#     'lat': 55.844809,
#     'lng': 37.006161,
#     'description': None,
#     'raw': 'деревня Аносино, Университетская улица, вл11',
#     'metro': None,
#     'metro_stations': [],
#     'id': '16364377'},
#    'response_url': None,
#    'sort_point_distance': None,
#    'published_at': '2024-08-20T14:14:14+0300',
#    'created_at': '2024-08-20T14:14:14+0300',
#    'archived': False,
#    'apply_alternate_url': 'https://hh.ru/applicant/vacancy_response?vacancyId=106066250',
#    'show_logo_in_search': None,
#    'insider_interview': None,
#    'url': 'https://api.hh.ru/vacancies/106066250?host=hh.ru',
#    'alternate_url': 'https://hh.ru/vacancy/106066250',
#    'relations': [],
#    'employer': {'id': '787380',
#     'name': 'Бюро Фитодизайна Фикус',
#     'url': 'https://api.hh.ru/employers/787380',
#     'alternate_url': 'https://hh.ru/employer/787380',
#     'logo_urls': {'original': 'https://img.hhcdn.ru/employer-logo-original/941072.png',
#      '240': 'https://img.hhcdn.ru/employer-logo/4204829.png',
#      '90': 'https://img.hhcdn.ru/employer-logo/4204828.png'},
#     'vacancies_url': 'https://api.hh.ru/vacancies?employer_id=787380',
#     'accredited_it_employer': False,
#     'trusted': True},
#    'snippet': {'requirement': 'Организованность. Высокая ответственность. Пунктуальность. Аккуратность. Внимательность. Будет преимуществом профильное образование (<highlighttext>агроном</highlighttext>, почвовед, агрохимик, ландшафтный архитектор, садовод, биолог, лесное дело и...',
#     'responsibility': 'Комплексный уход за растениями включает в себя: -полив растений. -удаление пыли с листьев. -формирование кроны. -подсыпка грунта. -своевременная диагностика болезней...'},
#    'contacts': None,
#    'schedule': {'id': 'fullDay', 'name': 'Полный день'},
#    'working_days': [],
#    'working_time_intervals': [],
#    'working_time_modes': [],
#    'accept_temporary': False,
#    'professional_roles': [{'id': '40', 'name': 'Другое'}],
#    'accept_incomplete_resumes': True,
#    'experience': {'id': 'between1And3', 'name': 'От 1 года до 3 лет'},
#    'employment': {'id': 'full', 'name': 'Полная занятость'},
#    'adv_response_url': None,
#    'is_adv_vacancy': False,
#    'adv_context': None},
#   {'id': '106702001',
#    'premium': False,
#    'name': 'Агроном (Растениеводство)',
#    'department': None,
#    'has_test': False,
#    'response_letter_required': False,
#    'area': {'id': '1', 'name': 'Москва', 'url': 'https://api.hh.ru/areas/1'},
#    'salary': {'from': 130000, 'to': 150000, 'currency': 'RUR', 'gross': False},
#    'type': {'id': 'open', 'name': 'Открытая'},
#    'address': {'city': 'деревня Кончинка',
#     'street': None,
#     'building': None,
#     'lat': 54.678276,
#     'lng': 38.157702,
#     'description': None,
#     'raw': 'деревня Кончинка',
#     'metro': None,
#     'metro_stations': [],
#     'id': '1889665'},
#    'response_url': None,
#    'sort_point_distance': None,
#    'published_at': '2024-09-12T11:55:28+0300',
#    'created_at': '2024-09-12T11:55:28+0300',
#    'archived': False,
#    'apply_alternate_url': 'https://hh.ru/applicant/vacancy_response?vacancyId=106702001',
#    'show_logo_in_search': None,
#    'insider_interview': None,
#    'url': 'https://api.hh.ru/vacancies/106702001?host=hh.ru',
#    'alternate_url': 'https://hh.ru/vacancy/106702001',
#    'relations': [],
#    'employer': {'id': '161720',
#     'name': 'КОРНИ, Питомник растений',
#     'url': 'https://api.hh.ru/employers/161720',
#     'alternate_url': 'https://hh.ru/employer/161720',
#     'logo_urls': {'240': 'https://img.hhcdn.ru/employer-logo/2772456.png',
#      '90': 'https://img.hhcdn.ru/employer-logo/2772455.png',
#      'original': 'https://img.hhcdn.ru/employer-logo-original/582800.png'},
#     'vacancies_url': 'https://api.hh.ru/vacancies?employer_id=161720',
#     'accredited_it_employer': False,
#     'trusted': True},
#    'snippet': {'requirement': 'Опыт работы в питомнике, садовом центре или овощеводческом предприятии от 3 лет. Опыт работы на руководящей должности (начальник, бригадир и...',
#     'responsibility': 'Организовывать процесса размножения и выращивания декоративных растений. Внедрять и контролировать соблюдение технологий выращивания растений. Своевременное выявлять болезни, вредителей в почве...'},
#    'contacts': None,
#    'schedule': {'id': 'fullDay', 'name': 'Полный день'},
#    'working_days': [],
#    'working_time_intervals': [],
#    'working_time_modes': [],
#    'accept_temporary': True,
#    'professional_roles': [{'id': '7', 'name': 'Агроном'}],
#    'accept_incomplete_resumes': True,
#    'experience': {'id': 'between3And6', 'name': 'От 3 до 6 лет'},
#    'employment': {'id': 'full', 'name': 'Полная занятость'},
#    'adv_response_url': None,
#    'is_adv_vacancy': False,
#    'adv_context': None},
#   {'id': '107065128',
#    'premium': False,
#    'name': 'Специалист по уходу за офисными растениями (садовник-агроном / биолог-фитопатолог)',
#    'department': None,
#    'has_test': False,
#    'response_letter_required': False,
#    'area': {'id': '1', 'name': 'Москва', 'url': 'https://api.hh.ru/areas/1'},
#    'salary': {'from': 25000, 'to': 100000, 'currency': 'RUR', 'gross': False},
#    'type': {'id': 'open', 'name': 'Открытая'},
#    'address': {'city': 'Москва',
#     'street': 'Пресненская набережная',
#     'building': '12',
#     'lat': 55.749633,
#     'lng': 37.537434,
#     'description': None,
#     'raw': 'Москва, Пресненская набережная, 12',
#     'metro': {'station_name': 'Деловой центр',
#      'line_name': 'Солнцевская',
#      'station_id': '133.468',
#      'line_id': '133',
#      'lat': 55.7491,
#      'lng': 37.5395},
#     'metro_stations': [{'station_name': 'Деловой центр',
#       'line_name': 'Солнцевская',
#       'station_id': '133.468',
#       'line_id': '133',
#       'lat': 55.7491,
#       'lng': 37.5395}],
#     'id': '11920647'},
#    'response_url': None,
#    'sort_point_distance': None,
#    'published_at': '2024-09-10T15:15:41+0300',
#    'created_at': '2024-09-10T15:15:41+0300',
#    'archived': False,
#    'apply_alternate_url': 'https://hh.ru/applicant/vacancy_response?vacancyId=107065128',
#    'insider_interview': None,
#    'url': 'https://api.hh.ru/vacancies/107065128?host=hh.ru',
#    'alternate_url': 'https://hh.ru/vacancy/107065128',
#    'relations': [],
#    'employer': {'id': '3926338',
#     'name': 'Дизайн Инжиниринг',
#     'url': 'https://api.hh.ru/employers/3926338',
#     'alternate_url': 'https://hh.ru/employer/3926338',
#     'logo_urls': None,
#     'vacancies_url': 'https://api.hh.ru/vacancies?employer_id=3926338',
#     'accredited_it_employer': False,
#     'trusted': True},
#    'snippet': {'requirement': 'Диплом об профильном образовании (высшее, минимум среднее специальное). Опыт работы от 1 лет обязателен.',
#     'responsibility': 'Комплексный уход за офисными растениями. Знание болезней и вредителей растений. Умение вести профилактическую работу с растениями. Подбор эффективного лечения растений...'},
#    'contacts': None,
#    'schedule': {'id': 'flexible', 'name': 'Гибкий график'},
#    'working_days': [],
#    'working_time_intervals': [{'id': 'from_four_to_six_hours_in_a_day',
#      'name': 'Можно сменами по\xa04-6\xa0часов в\xa0день'}],
#    'working_time_modes': [],
#    'accept_temporary': True,
#    'professional_roles': [{'id': '7', 'name': 'Агроном'}],
#    'accept_incomplete_resumes': False,
#    'experience': {'id': 'between1And3', 'name': 'От 1 года до 3 лет'},
#    'employment': {'id': 'part', 'name': 'Частичная занятость'},
#    'adv_response_url': None,
#    'is_adv_vacancy': False,
#    'adv_context': None},
#   {'id': '106267536',
#    'premium': False,
#    'name': 'Агроном',
#    'department': None,
#    'has_test': False,
#    'response_letter_required': False,
#    'area': {'id': '1', 'name': 'Москва', 'url': 'https://api.hh.ru/areas/1'},
#    'salary': {'from': 80000, 'to': None, 'currency': 'RUR', 'gross': False},
#    'type': {'id': 'open', 'name': 'Открытая'},
#    'address': None,
#    'response_url': None,
#    'sort_point_distance': None,
#    'published_at': '2024-09-10T15:49:41+0300',
#    'created_at': '2024-09-10T15:49:41+0300',
#    'archived': False,
#    'apply_alternate_url': 'https://hh.ru/applicant/vacancy_response?vacancyId=106267536',
#    'show_logo_in_search': None,
#    'insider_interview': None,
#    'url': 'https://api.hh.ru/vacancies/106267536?host=hh.ru',
#    'alternate_url': 'https://hh.ru/vacancy/106267536',
#    'relations': [],
#    'employer': {'id': '1197490',
#     'name': 'Озеленитель Стройгруп',
#     'url': 'https://api.hh.ru/employers/1197490',
#     'alternate_url': 'https://hh.ru/employer/1197490',
#     'logo_urls': {'original': 'https://img.hhcdn.ru/employer-logo-original/58989.jpg',
#      '90': 'https://img.hhcdn.ru/employer-logo/875324.jpeg',
#      '240': 'https://img.hhcdn.ru/employer-logo/875325.jpeg'},
#     'vacancies_url': 'https://api.hh.ru/vacancies?employer_id=1197490',
#     'accredited_it_employer': False,
#     'trusted': True},
#    'snippet': {'requirement': 'Образование не ниже среднего специального (агрономия). Мы готовы рассмотреть выпускников ВУЗов по направлению агрономии, садоводства, лесного дела и кандидатов с...',
#     'responsibility': 'Все виды работ на объектах по уходу за плодовыми, хвойными, декоративно-лиственными, кустарниковыми и цветочными насаждениями. Посадка и пересадка растений. '},
#    'contacts': None,
#    'schedule': {'id': 'fullDay', 'name': 'Полный день'},
#    'working_days': [],
#    'working_time_intervals': [],
#    'working_time_modes': [],
#    'accept_temporary': False,
#    'professional_roles': [{'id': '7', 'name': 'Агроном'}],
#    'accept_incomplete_resumes': False,
#    'experience': {'id': 'noExperience', 'name': 'Нет опыта'},
#    'employment': {'id': 'full', 'name': 'Полная занятость'},
#    'adv_response_url': None,
#    'is_adv_vacancy': False,
#    'adv_context': None},
#   {'id': '92590473',
#    'premium': False,
#    'name': 'Специалист по сертификации (сельское хозяйство)',
#    'department': None,
#    'has_test': False,
#    'response_letter_required': False,
#    'area': {'id': '1', 'name': 'Москва', 'url': 'https://api.hh.ru/areas/1'},
#    'salary': {'from': None, 'to': 120000, 'currency': 'RUR', 'gross': True},
#    'type': {'id': 'open', 'name': 'Открытая'},
#    'address': {'city': 'Москва',
#     'street': 'Большой Трёхгорный переулок',
#     'building': '1/26с7',
#     'lat': 55.757602,
#     'lng': 37.563063,
#     'description': None,
#     'raw': 'Москва, Большой Трёхгорный переулок, 1/26с7',
#     'metro': {'station_name': 'Улица 1905 года',
#      'line_name': 'Таганско-Краснопресненская',
#      'station_id': '7.146',
#      'line_id': '7',
#      'lat': 55.763944,
#      'lng': 37.562271},
#     'metro_stations': [{'station_name': 'Улица 1905 года',
#       'line_name': 'Таганско-Краснопресненская',
#       'station_id': '7.146',
#       'line_id': '7',
#       'lat': 55.763944,
#       'lng': 37.562271}],
#     'id': '6854575'},
#    'response_url': None,
#    'sort_point_distance': None,
#    'published_at': '2024-08-25T17:58:20+0300',
#    'created_at': '2024-08-25T17:58:20+0300',
#    'archived': False,
#    'apply_alternate_url': 'https://hh.ru/applicant/vacancy_response?vacancyId=92590473',
#    'branding': {'type': 'MAKEUP', 'tariff': None},
#    'show_logo_in_search': True,
#    'insider_interview': None,
#    'url': 'https://api.hh.ru/vacancies/92590473?host=hh.ru',
#    'alternate_url': 'https://hh.ru/vacancy/92590473',
#    'relations': [],
#    'employer': {'id': '5730496',
#     'name': 'Major Agro',
#     'url': 'https://api.hh.ru/employers/5730496',
#     'alternate_url': 'https://hh.ru/employer/5730496',
#     'logo_urls': {'original': 'https://img.hhcdn.ru/employer-logo-original/1071109.png',
#      '240': 'https://img.hhcdn.ru/employer-logo/5905066.png',
#      '90': 'https://img.hhcdn.ru/employer-logo/5905065.png'},
#     'vacancies_url': 'https://api.hh.ru/vacancies?employer_id=5730496',
#     'accredited_it_employer': False,
#     'trusted': True},
#    'snippet': {'requirement': 'Высшее/среднее специальное профильное образование (<highlighttext>агроном</highlighttext>, <highlighttext>агроном</highlighttext>-эколог и т.д.). Стаж работы от 1 года желателен. Уверенный пользователь MS...',
#     'responsibility': 'Проведение работ по сертификации органической продукции (ГОСТ 33980-2016, ГОСТ Р 57022–2016, ГОСТ Р 56104-2014, Европейский Регламент 2018...'},
#    'contacts': None,
#    'schedule': {'id': 'fullDay', 'name': 'Полный день'},
#    'working_days': [],
#    'working_time_intervals': [],
#    'working_time_modes': [],
#    'accept_temporary': False,
#    'professional_roles': [{'id': '151', 'name': 'Специалист по сертификации'}],
#    'accept_incomplete_resumes': False,
#    'experience': {'id': 'between1And3', 'name': 'От 1 года до 3 лет'},
#    'employment': {'id': 'full', 'name': 'Полная занятость'},
#    'adv_response_url': None,
#    'is_adv_vacancy': False,
#    'adv_context': None},
#   {'id': '106107473',
#    'premium': False,
#    'name': 'Агроном',
#    'department': None,
#    'has_test': False,
#    'response_letter_required': False,
#    'area': {'id': '1', 'name': 'Москва', 'url': 'https://api.hh.ru/areas/1'},
#    'salary': {'from': 50000, 'to': 100000, 'currency': 'RUR', 'gross': False},
#    'type': {'id': 'open', 'name': 'Открытая'},
#    'address': None,
#    'response_url': None,
#    'sort_point_distance': None,
#    'published_at': '2024-08-21T11:17:36+0300',
#    'created_at': '2024-08-21T11:17:36+0300',
#    'archived': False,
#    'apply_alternate_url': 'https://hh.ru/applicant/vacancy_response?vacancyId=106107473',
#    'show_logo_in_search': None,
#    'insider_interview': None,
#    'url': 'https://api.hh.ru/vacancies/106107473?host=hh.ru',
#    'alternate_url': 'https://hh.ru/vacancy/106107473',
#    'relations': [],
#    'employer': {'id': '10797718',
#     'name': 'Райдер СНГ',
#     'url': 'https://api.hh.ru/employers/10797718',
#     'alternate_url': 'https://hh.ru/employer/10797718',
#     'logo_urls': {'original': 'https://img.hhcdn.ru/employer-logo-original/1255026.png',
#      '90': 'https://img.hhcdn.ru/employer-logo/6640533.png',
#      '240': 'https://img.hhcdn.ru/employer-logo/6640534.png'},
#     'vacancies_url': 'https://api.hh.ru/vacancies?employer_id=10797718',
#     'accredited_it_employer': False,
#     'trusted': True},
#    'snippet': {'requirement': 'Tребовaния к вaм:  Bысшee или сpедне-cпециaльное агpономическое/агрохимическое образование.  Знание технологии выращивания овощей и цветов.  Опыт работы желателен, но...',
#     'responsibility': 'Рaйдер Cидc – производственная cелeкционно-cеменовoдчеcкaя кoмпaния, являющaяcя надежным поcтaвщикoм семян овoщныx культуp ищeт aгрoнoмa Готовы рассмотреть в том числе кандидата...'},
#    'contacts': None,
#    'schedule': {'id': 'fullDay', 'name': 'Полный день'},
#    'working_days': [],
#    'working_time_intervals': [],
#    'working_time_modes': [],
#    'accept_temporary': False,
#    'professional_roles': [{'id': '7', 'name': 'Агроном'}],
#    'accept_incomplete_resumes': False,
#    'experience': {'id': 'noExperience', 'name': 'Нет опыта'},
#    'employment': {'id': 'full', 'name': 'Полная занятость'},
#    'adv_response_url': None,
#    'is_adv_vacancy': False,
#    'adv_context': None},
#   {'id': '106910336',
#    'premium': False,
#    'name': 'Агроном',
#    'department': None,
#    'has_test': False,
#    'response_letter_required': False,
#    'area': {'id': '1', 'name': 'Москва', 'url': 'https://api.hh.ru/areas/1'},
#    'salary': {'from': 88000, 'to': None, 'currency': 'RUR', 'gross': False},
#    'type': {'id': 'open', 'name': 'Открытая'},
#    'address': {'city': 'село Ильинское',
#     'street': 'Экспериментальная улица',
#     'building': '14',
#     'lat': 55.762115,
#     'lng': 37.229132,
#     'description': None,
#     'raw': 'село Ильинское, Экспериментальная улица, 14',
#     'metro': None,
#     'metro_stations': [],
#     'id': '15001429'},
#    'response_url': None,
#    'sort_point_distance': None,
#    'published_at': '2024-09-06T14:36:02+0300',
#    'created_at': '2024-09-06T14:36:02+0300',
#    'archived': False,
#    'apply_alternate_url': 'https://hh.ru/applicant/vacancy_response?vacancyId=106910336',
#    'show_logo_in_search': None,
#    'insider_interview': None,
#    'url': 'https://api.hh.ru/vacancies/106910336?host=hh.ru',
#    'alternate_url': 'https://hh.ru/vacancy/106910336',
#    'relations': [],
#    'employer': {'id': '4438089',
#     'name': 'ЭкоПлантТ',
#     'url': 'https://api.hh.ru/employers/4438089',
#     'alternate_url': 'https://hh.ru/employer/4438089',
#     'logo_urls': {'90': 'https://img.hhcdn.ru/employer-logo/6764678.jpeg',
#      'original': 'https://img.hhcdn.ru/employer-logo-original/1286095.jpeg',
#      '240': 'https://img.hhcdn.ru/employer-logo/6764679.jpeg'},
#     'vacancies_url': 'https://api.hh.ru/vacancies?employer_id=4438089',
#     'accredited_it_employer': False,
#     'trusted': True},
#    'snippet': {'requirement': 'Опыт работы агрономом или садовником, возможно выпускник по специальностям связанным с агрономией, без опыта работы. Всесторонние знания в области агрономии...',
#     'responsibility': 'Организация и проведение работ по: Дендрологическим обследованиям зеленых насаждений, контролю за посадкой декоративных растений и крупномеров. Проведению посадочных мероприятий; контролю...'},
#    'contacts': None,
#    'schedule': {'id': 'fullDay', 'name': 'Полный день'},
#    'working_days': [],
#    'working_time_intervals': [],
#    'working_time_modes': [],
#    'accept_temporary': False,
#    'professional_roles': [{'id': '7', 'name': 'Агроном'}],
#    'accept_incomplete_resumes': True,
#    'experience': {'id': 'between1And3', 'name': 'От 1 года до 3 лет'},
#    'employment': {'id': 'full', 'name': 'Полная занятость'},
#    'adv_response_url': None,
#    'is_adv_vacancy': False,
#    'adv_context': None},
#   {'id': '106773968',
#    'premium': False,
#    'name': 'Садовник-агроном (м. Ботанический сад)',
#    'department': None,
#    'has_test': False,
#    'response_letter_required': False,
#    'area': {'id': '1', 'name': 'Москва', 'url': 'https://api.hh.ru/areas/1'},
#    'salary': {'from': 80000, 'to': 80000, 'currency': 'RUR', 'gross': False},
#    'type': {'id': 'open', 'name': 'Открытая'},
#    'address': None,
#    'response_url': None,
#    'sort_point_distance': None,
#    'published_at': '2024-09-04T12:57:31+0300',
#    'created_at': '2024-09-04T12:57:31+0300',
#    'archived': False,
#    'apply_alternate_url': 'https://hh.ru/applicant/vacancy_response?vacancyId=106773968',
#    'show_logo_in_search': None,
#    'insider_interview': None,
#    'url': 'https://api.hh.ru/vacancies/106773968?host=hh.ru',
#    'alternate_url': 'https://hh.ru/vacancy/106773968',
#    'relations': [],
#    'employer': {'id': '5036807',
#     'name': 'ГК ВЫСОТА - СЕРВИС (ООО УК ВЫСОТА 4884. СЕРВИС)',
#     'url': 'https://api.hh.ru/employers/5036807',
#     'alternate_url': 'https://hh.ru/employer/5036807',
#     'logo_urls': {'original': 'https://img.hhcdn.ru/employer-logo-original/904560.jpg',
#      '90': 'https://img.hhcdn.ru/employer-logo/4058927.jpeg',
#      '240': 'https://img.hhcdn.ru/employer-logo/4058928.jpeg'},
#     'vacancies_url': 'https://api.hh.ru/vacancies?employer_id=5036807',
#     'accredited_it_employer': False,
#     'trusted': True},
#    'snippet': {'requirement': 'Образование: среднее профессиональное, высшее, курсы повышения квалификации. Опыт работы в сфере от 2 лет. Исполнительность. Работоспособность. Творческий подход.',
#     'responsibility': 'Проведение регулярных осмотров территории, мониторинга зеленых насаждений, выявление повреждений с оформлением соответствующей документации. Составление планов работ, формирование закупок. '},
#    'contacts': None,
#    'schedule': {'id': 'fullDay', 'name': 'Полный день'},
#    'working_days': [],
#    'working_time_intervals': [],
#    'working_time_modes': [],
#    'accept_temporary': True,
#    'professional_roles': [{'id': '7', 'name': 'Агроном'}],
#    'accept_incomplete_resumes': False,
#    'experience': {'id': 'between1And3', 'name': 'От 1 года до 3 лет'},
#    'employment': {'id': 'full', 'name': 'Полная занятость'},
#    'adv_response_url': None,
#    'is_adv_vacancy': False,
#    'adv_context': None},
#   {'id': '105834528',
#    'premium': False,
#    'name': 'Флорист-агроном в шоурум флорариумов',
#    'department': None,
#    'has_test': False,
#    'response_letter_required': False,
#    'area': {'id': '1', 'name': 'Москва', 'url': 'https://api.hh.ru/areas/1'},
#    'salary': {'from': 70000, 'to': 100000, 'currency': 'RUR', 'gross': False},
#    'type': {'id': 'open', 'name': 'Открытая'},
#    'address': {'city': 'Москва',
#     'street': 'Садовая-Кудринская улица',
#     'building': '20',
#     'lat': 55.762404,
#     'lng': 37.587973,
#     'description': None,
#     'raw': 'Москва, Садовая-Кудринская улица, 20',
#     'metro': {'station_name': 'Баррикадная',
#      'line_name': 'Таганско-Краснопресненская',
#      'station_id': '7.16',
#      'line_id': '7',
#      'lat': 55.760793,
#      'lng': 37.581242},
#     'metro_stations': [{'station_name': 'Баррикадная',
#       'line_name': 'Таганско-Краснопресненская',
#       'station_id': '7.16',
#       'line_id': '7',
#       'lat': 55.760793,
#       'lng': 37.581242},
#      {'station_name': 'Краснопресненская',
#       'line_name': 'Кольцевая',
#       'station_id': '5.58',
#       'line_id': '5',
#       'lat': 55.760378,
#       'lng': 37.577114},
#      {'station_name': 'Маяковская',
#       'line_name': 'Замоскворецкая',
#       'station_id': '2.80',
#       'line_id': '2',
#       'lat': 55.769808,
#       'lng': 37.596192},
#      {'station_name': 'Тверская',
#       'line_name': 'Замоскворецкая',
#       'station_id': '2.122',
#       'line_id': '2',
#       'lat': 55.765343,
#       'lng': 37.603918}],
#     'id': '16080943'},
#    'response_url': None,
#    'sort_point_distance': None,
#    'published_at': '2024-09-11T09:31:53+0300',
#    'created_at': '2024-09-11T09:31:53+0300',
#    'archived': False,
#    'apply_alternate_url': 'https://hh.ru/applicant/vacancy_response?vacancyId=105834528',
#    'show_logo_in_search': None,
#    'insider_interview': None,
#    'url': 'https://api.hh.ru/vacancies/105834528?host=hh.ru',
#    'alternate_url': 'https://hh.ru/vacancy/105834528',
#    'relations': [],
#    'employer': {'id': '5888368',
#     'name': 'NEOPURE',
#     'url': 'https://api.hh.ru/employers/5888368',
#     'alternate_url': 'https://hh.ru/employer/5888368',
#     'logo_urls': {'240': 'https://img.hhcdn.ru/employer-logo/6596082.jpeg',
#      '90': 'https://img.hhcdn.ru/employer-logo/6596081.jpeg',
#      'original': 'https://img.hhcdn.ru/employer-logo-original/1243912.jpg'},
#     'vacancies_url': 'https://api.hh.ru/vacancies?employer_id=5888368',
#     'accredited_it_employer': False,
#     'trusted': True},
#    'snippet': {'requirement': 'Знание ассортимента комнатных растений. Знание компонентов грунта. Знание основных вредителей и болезней, умение подобрать правильное лечение. Инициативность, ответственность, умение взять...',
#     'responsibility': 'Общение с посетителями шоурума. Сборка и отправка заказов. Сборка флорариумов. Работа с горшечными растениями. Ведение таблиц учёта. Поддержание порядка и...'},
#    'contacts': None,
#    'schedule': {'id': 'fullDay', 'name': 'Полный день'},
#    'working_days': [],
#    'working_time_intervals': [],
#    'working_time_modes': [],
#    'accept_temporary': False,
#    'professional_roles': [{'id': '40', 'name': 'Другое'}],
#    'accept_incomplete_resumes': True,
#    'experience': {'id': 'between1And3', 'name': 'От 1 года до 3 лет'},
#    'employment': {'id': 'full', 'name': 'Полная занятость'},
#    'adv_response_url': None,
#    'is_adv_vacancy': False,
#    'adv_context': None},
#   {'id': '106755789',
#    'premium': False,
#    'name': 'Менеджер по технологическому сопровождению/ Агроном-консультант',
#    'department': None,
#    'has_test': False,
#    'response_letter_required': False,
#    'area': {'id': '1', 'name': 'Москва', 'url': 'https://api.hh.ru/areas/1'},
#    'salary': None,
#    'type': {'id': 'open', 'name': 'Открытая'},
#    'address': None,
#    'response_url': None,
#    'sort_point_distance': None,
#    'published_at': '2024-09-10T10:14:11+0300',
#    'created_at': '2024-09-10T10:14:11+0300',
#    'archived': False,
#    'apply_alternate_url': 'https://hh.ru/applicant/vacancy_response?vacancyId=106755789',
#    'show_logo_in_search': None,
#    'insider_interview': None,
#    'url': 'https://api.hh.ru/vacancies/106755789?host=hh.ru',
#    'alternate_url': 'https://hh.ru/vacancy/106755789',
#    'relations': [],
#    'employer': {'id': '122438',
#     'name': 'Агрорус',
#     'url': 'https://api.hh.ru/employers/122438',
#     'alternate_url': 'https://hh.ru/employer/122438',
#     'logo_urls': {'original': 'https://img.hhcdn.ru/employer-logo-original/205425.JPG',
#      '90': 'https://img.hhcdn.ru/employer-logo/336465.jpeg',
#      '240': 'https://img.hhcdn.ru/employer-logo/409322.jpeg'},
#     'vacancies_url': 'https://api.hh.ru/vacancies?employer_id=122438',
#     'accredited_it_employer': False,
#     'trusted': True},
#    'snippet': {'requirement': 'Образование: высшее профессиональное образование (агрономия, защита растений, агрохимия и т.п.). Опыт работы в сельскохозяйственном производстве. Знание актуальных систем возделывания...',
#     'responsibility': 'Выезд в хозяйства на вверенной территории, закладка демонстрационных испытаний и производственных опытов по препаратам компании. Контроль внесения препаратов, отслеживание результатов...'},
#    'contacts': None,
#    'schedule': {'id': 'fullDay', 'name': 'Полный день'},
#    'working_days': [],
#    'working_time_intervals': [],
#    'working_time_modes': [],
#    'accept_temporary': False,
#    'professional_roles': [{'id': '7', 'name': 'Агроном'}],
#    'accept_incomplete_resumes': False,
#    'experience': {'id': 'between3And6', 'name': 'От 3 до 6 лет'},
#    'employment': {'id': 'full', 'name': 'Полная занятость'},
#    'adv_response_url': None,
#    'is_adv_vacancy': False,
#    'adv_context': None},
#   {'id': '106019565',
#    'premium': False,
#    'name': 'Агроном (садовник)',
#    'department': None,
#    'has_test': False,
#    'response_letter_required': False,
#    'area': {'id': '1', 'name': 'Москва', 'url': 'https://api.hh.ru/areas/1'},
#    'salary': {'from': 160000, 'to': 180000, 'currency': 'RUR', 'gross': False},
#    'type': {'id': 'open', 'name': 'Открытая'},
#    'address': {'city': 'Москва',
#     'street': 'Выборгская улица',
#     'building': '9Ас1',
#     'lat': 55.836438,
#     'lng': 37.499381,
#     'description': None,
#     'raw': 'Москва, Выборгская улица, 9Ас1',
#     'metro': None,
#     'metro_stations': [],
#     'id': '14299377'},
#    'response_url': None,
#    'sort_point_distance': None,
#    'published_at': '2024-08-19T17:55:15+0300',
#    'created_at': '2024-08-19T17:55:15+0300',
#    'archived': False,
#    'apply_alternate_url': 'https://hh.ru/applicant/vacancy_response?vacancyId=106019565',
#    'show_logo_in_search': None,
#    'insider_interview': None,
#    'url': 'https://api.hh.ru/vacancies/106019565?host=hh.ru',
#    'alternate_url': 'https://hh.ru/vacancy/106019565',
#    'relations': [],
#    'employer': {'id': '2302207',
#     'name': 'КРОСТ',
#     'url': 'https://api.hh.ru/employers/2302207',
#     'alternate_url': 'https://hh.ru/employer/2302207',
#     'logo_urls': {'240': 'https://img.hhcdn.ru/employer-logo/2806512.jpeg',
#      '90': 'https://img.hhcdn.ru/employer-logo/2806511.jpeg',
#      'original': 'https://img.hhcdn.ru/employer-logo-original/591314.jpg'},
#     'vacancies_url': 'https://api.hh.ru/vacancies?employer_id=2302207',
#     'accredited_it_employer': False,
#     'trusted': True},
#    'snippet': {'requirement': 'Высшее агрономическое образование (Тимирязевская СХ Академия, МГУЛ, др. СХ Вузы). Опыт работы от 3-х лет (опыт работы с крупных...',
#     'responsibility': 'Проведение дендрологических обследований зеленых насаждений. Подбор ассортимента посадочного материала для реализации проектных решений. Контроль при закупке посадочного материала и садовой...'},
#    'contacts': None,
#    'schedule': {'id': 'fullDay', 'name': 'Полный день'},
#    'working_days': [],
#    'working_time_intervals': [],
#    'working_time_modes': [],
#    'accept_temporary': False,
#    'professional_roles': [{'id': '7', 'name': 'Агроном'}],
#    'accept_incomplete_resumes': False,
#    'experience': {'id': 'between3And6', 'name': 'От 3 до 6 лет'},
#    'employment': {'id': 'full', 'name': 'Полная занятость'},
#    'adv_response_url': None,
#    'is_adv_vacancy': False,
#    'adv_context': None},
#   {'id': '106041540',
#    'premium': False,
#    'name': 'Производственный директор - Главный агроном (Растениеводство)',
#    'department': None,
#    'has_test': False,
#    'response_letter_required': False,
#    'area': {'id': '1', 'name': 'Москва', 'url': 'https://api.hh.ru/areas/1'},
#    'salary': {'from': 200000, 'to': 300000, 'currency': 'RUR', 'gross': True},
#    'type': {'id': 'open', 'name': 'Открытая'},
#    'address': {'city': 'Москва',
#     'street': None,
#     'building': None,
#     'lat': 55.685026,
#     'lng': 37.733904,
#     'description': None,
#     'raw': 'Москва',
#     'metro': None,
#     'metro_stations': [],
#     'id': '16102152'},
#    'response_url': None,
#    'sort_point_distance': None,
#    'published_at': '2024-08-20T10:23:03+0300',
#    'created_at': '2024-08-20T10:23:03+0300',
#    'archived': False,
#    'apply_alternate_url': 'https://hh.ru/applicant/vacancy_response?vacancyId=106041540',
#    'insider_interview': None,
#    'url': 'https://api.hh.ru/vacancies/106041540?host=hh.ru',
#    'alternate_url': 'https://hh.ru/vacancy/106041540',
#    'relations': [],
#    'employer': {'id': '1689259',
#     'name': 'ДЖЕЙКЕТ РАБОТА',
#     'url': 'https://api.hh.ru/employers/1689259',
#     'alternate_url': 'https://hh.ru/employer/1689259',
#     'logo_urls': None,
#     'vacancies_url': 'https://api.hh.ru/vacancies?employer_id=1689259',
#     'accredited_it_employer': False,
#     'trusted': True},
#    'snippet': {'requirement': 'Знающий и умеющий работать с агрономической документацией, а также со складской, производственной, упаковочной, отгрузочной документацией. Нацеленный не только на доскональное...',
#     'responsibility': 'Качество готовой продукции соответствует как внутренним стандартам качества, так и ГОСТам. Методы управления производственной очередью гарантируют исполнение сроков отгрузки готовой...'},
#    'contacts': None,
#    'schedule': {'id': 'fullDay', 'name': 'Полный день'},
#    'working_days': [],
#    'working_time_intervals': [],
#    'working_time_modes': [],
#    'accept_temporary': False,
#    'professional_roles': [{'id': '87', 'name': 'Операционный директор (COO)'}],
#    'accept_incomplete_resumes': True,
#    'experience': {'id': 'moreThan6', 'name': 'Более 6 лет'},
#    'employment': {'id': 'full', 'name': 'Полная занятость'},
#    'adv_response_url': None,
#    'is_adv_vacancy': False,
#    'adv_context': None},
#   {'id': '105991117',
#    'premium': False,
#    'name': 'Агроном-садовник',
#    'department': None,
#    'has_test': False,
#    'response_letter_required': False,
#    'area': {'id': '1', 'name': 'Москва', 'url': 'https://api.hh.ru/areas/1'},
#    'salary': {'from': 100000, 'to': 150000, 'currency': 'RUR', 'gross': False},
#    'type': {'id': 'open', 'name': 'Открытая'},
#    'address': {'city': 'Московский поселение',
#     'street': '22-й километр',
#     'building': '4стр1',
#     'lat': 55.634151,
#     'lng': 37.441026,
#     'description': None,
#     'raw': 'Московский поселение, 22-й километр, 4стр1',
#     'metro': {'station_name': 'Румянцево',
#      'line_name': 'Сокольническая',
#      'station_id': '1.513',
#      'line_id': '1',
#      'lat': 55.633,
#      'lng': 37.4419},
#     'metro_stations': [{'station_name': 'Румянцево',
#       'line_name': 'Сокольническая',
#       'station_id': '1.513',
#       'line_id': '1',
#       'lat': 55.633,
#       'lng': 37.4419}],
#     'id': '16417700'},
#    'response_url': None,
#    'sort_point_distance': None,
#    'published_at': '2024-09-12T12:30:19+0300',
#    'created_at': '2024-09-12T12:30:19+0300',
#    'archived': False,
#    'apply_alternate_url': 'https://hh.ru/applicant/vacancy_response?vacancyId=105991117',
#    'insider_interview': None,
#    'url': 'https://api.hh.ru/vacancies/105991117?host=hh.ru',
#    'alternate_url': 'https://hh.ru/vacancy/105991117',
#    'relations': [],
#    'employer': {'id': '1689259',
#     'name': 'ДЖЕЙКЕТ РАБОТА',
#     'url': 'https://api.hh.ru/employers/1689259',
#     'alternate_url': 'https://hh.ru/employer/1689259',
#     'logo_urls': None,
#     'vacancies_url': 'https://api.hh.ru/vacancies?employer_id=1689259',
#     'accredited_it_employer': False,
#     'trusted': True},
#    'snippet': {'requirement': 'Знание растений Подмосковья и способы ухода за ними. Образование - аграрный колледж или институт. Умение работать садовым инструментом. Аккуратность и трудолюбие. ',
#     'responsibility': 'Самостоятельный уход за растениями. Руководство бригадой рабочих для сервисного обслуживания зеленых насаждений на территории клиентов. Реализация проектов по благоустройству и...'},
#    'contacts': None,
#    'schedule': {'id': 'flexible', 'name': 'Гибкий график'},
#    'working_days': [],
#    'working_time_intervals': [],
#    'working_time_modes': [],
#    'accept_temporary': False,
#    'professional_roles': [{'id': '7', 'name': 'Агроном'}],
#    'accept_incomplete_resumes': True,
#    'experience': {'id': 'between1And3', 'name': 'От 1 года до 3 лет'},
#    'employment': {'id': 'full', 'name': 'Полная занятость'},
#    'adv_response_url': None,
#    'is_adv_vacancy': False,
#    'adv_context': None},
#   {'id': '105045436',
#    'premium': False,
#    'name': 'Агроном',
#    'department': None,
#    'has_test': False,
#    'response_letter_required': False,
#    'area': {'id': '1', 'name': 'Москва', 'url': 'https://api.hh.ru/areas/1'},
#    'salary': {'from': None, 'to': 80000, 'currency': 'RUR', 'gross': False},
#    'type': {'id': 'open', 'name': 'Открытая'},
#    'address': {'city': 'Москва',
#     'street': 'Рябиновая улица',
#     'building': '44с28',
#     'lat': 55.673306,
#     'lng': 37.432115,
#     'description': None,
#     'raw': 'Москва, Рябиновая улица, 44с28',
#     'metro': {'station_name': 'Говорово',
#      'line_name': 'Солнцевская',
#      'station_id': '133.609',
#      'line_id': '133',
#      'lat': 55.6588,
#      'lng': 37.4174},
#     'metro_stations': [{'station_name': 'Говорово',
#       'line_name': 'Солнцевская',
#       'station_id': '133.609',
#       'line_id': '133',
#       'lat': 55.6588,
#       'lng': 37.4174},
#      {'station_name': 'Озёрная',
#       'line_name': 'Солнцевская',
#       'station_id': '133.608',
#       'line_id': '133',
#       'lat': 55.6698,
#       'lng': 37.4495},
#      {'station_name': 'Сколково',
#       'line_name': 'МЦД-1',
#       'station_id': '131.708',
#       'line_id': '131',
#       'lat': 55.666801,
#       'lng': 37.424618}],
#     'id': '5597783'},
#    'response_url': None,
#    'sort_point_distance': None,
#    'published_at': '2024-08-22T08:56:51+0300',
#    'created_at': '2024-08-22T08:56:51+0300',
#    'archived': False,
#    'apply_alternate_url': 'https://hh.ru/applicant/vacancy_response?vacancyId=105045436',
#    'show_logo_in_search': None,
#    'insider_interview': None,
#    'url': 'https://api.hh.ru/vacancies/105045436?host=hh.ru',
#    'alternate_url': 'https://hh.ru/vacancy/105045436',
#    'relations': [],
#    'employer': {'id': '2756417',
#     'name': 'МИЛТИ',
#     'url': 'https://api.hh.ru/employers/2756417',
#     'alternate_url': 'https://hh.ru/employer/2756417',
#     'logo_urls': {'240': 'https://img.hhcdn.ru/employer-logo/3733484.jpeg',
#      '90': 'https://img.hhcdn.ru/employer-logo/3733483.jpeg',
#      'original': 'https://img.hhcdn.ru/employer-logo-original/823149.JPG'},
#     'vacancies_url': 'https://api.hh.ru/vacancies?employer_id=2756417',
#     'accredited_it_employer': False,
#     'trusted': True},
#    'snippet': {'requirement': 'Наличие опыта работы по уходу за растениями от 1 года приветствуется. Высшее профильное образование.',
#     'responsibility': 'Уход за растениями. Работа в теплице (сбор урожая, перестановка рассады, технические работы в соответствии с регламентом). Проверка работы оборудования, технического...'},
#    'contacts': None,
#    'schedule': {'id': 'fullDay', 'name': 'Полный день'},
#    'working_days': [],
#    'working_time_intervals': [],
#    'working_time_modes': [],
#    'accept_temporary': False,
#    'professional_roles': [{'id': '7', 'name': 'Агроном'}],
#    'accept_incomplete_resumes': False,
#    'experience': {'id': 'noExperience', 'name': 'Нет опыта'},
#    'employment': {'id': 'full', 'name': 'Полная занятость'},
#    'adv_response_url': None,
#    'is_adv_vacancy': False,
#    'adv_context': None},
#   {'id': '106243178',
#    'premium': False,
#    'name': 'Агроном',
#    'department': None,
#    'has_test': False,
# ...
#    'contacts': None,
#    'schedule': {'id': 'fullDay', 'name': 'Полный день'},
#    'working_days': [],
#    'working_time_intervals': [],
#    'working_time_modes': [],
#    'accept_temporary': True,
#    'professional_roles': [{'id': '40', 'name': 'Другое'}],
#    'accept_incomplete_resumes': False,
#    'experience': {'id': 'between1And3', 'name': 'От 1 года до 3 лет'},
#    'employment': {'id': 'full', 'name': 'Полная занятость'},
#    'adv_response_url': None,
#    'is_adv_vacancy': False,
#    'adv_context': None},
#   {'id': '105924903',
#    'premium': False,
#    'name': 'Выездной агроном на объекты клиентов',
#    'department': None,
#    'has_test': False,
#    'response_letter_required': False,
#    'area': {'id': '1', 'name': 'Москва', 'url': 'https://api.hh.ru/areas/1'},
#    'salary': {'from': 70000, 'to': 120000, 'currency': 'RUR', 'gross': False},
#    'type': {'id': 'open', 'name': 'Открытая'},
#    'address': {'city': 'село Ильинское',
#     'street': 'Экспериментальная улица',
#     'building': '14',
#     'lat': 55.762115,
#     'lng': 37.229132,
#     'description': None,
#     'raw': 'село Ильинское, Экспериментальная улица, 14',
#     'metro': None,
#     'metro_stations': [],
#     'id': '15001429'},
#    'response_url': None,
#    'sort_point_distance': None,
#    'published_at': '2024-08-16T15:18:04+0300',
#    'created_at': '2024-08-16T15:18:04+0300',
#    'archived': False,
#    'apply_alternate_url': 'https://hh.ru/applicant/vacancy_response?vacancyId=105924903',
#    'show_logo_in_search': None,
#    'insider_interview': None,
#    'url': 'https://api.hh.ru/vacancies/105924903?host=hh.ru',
#    'alternate_url': 'https://hh.ru/vacancy/105924903',
#    'relations': [],
#    'employer': {'id': '4438089',
#     'name': 'ЭкоПлантТ',
#     'url': 'https://api.hh.ru/employers/4438089',
#     'alternate_url': 'https://hh.ru/employer/4438089',
#     'logo_urls': {'90': 'https://img.hhcdn.ru/employer-logo/6764678.jpeg',
#      'original': 'https://img.hhcdn.ru/employer-logo-original/1286095.jpeg',
#      '240': 'https://img.hhcdn.ru/employer-logo/6764679.jpeg'},
#     'vacancies_url': 'https://api.hh.ru/vacancies?employer_id=4438089',
#     'accredited_it_employer': False,
#     'trusted': True},
#    'snippet': {'requirement': 'Опыт работы агрономом или садовником. Также рассматриваем выпускников по специальностям связанным с агрономией, без опыта работы. Всесторонние знания в области...',
#     'responsibility': 'Забирать из питомника рабочих (2-3 человека). Выезжать на объекты клиентов (5-6 объектов за день, все рядом территориально). '},
#    'contacts': None,
#    'schedule': {'id': 'fullDay', 'name': 'Полный день'},
#    'working_days': [],
#    'working_time_intervals': [],
#    'working_time_modes': [],
#    'accept_temporary': True,
#    'professional_roles': [{'id': '7', 'name': 'Агроном'}],
#    'accept_incomplete_resumes': False,
#    'experience': {'id': 'between1And3', 'name': 'От 1 года до 3 лет'},
#    'employment': {'id': 'full', 'name': 'Полная занятость'},
#    'adv_response_url': None,
#    'is_adv_vacancy': False,
#    'adv_context': None},
#   {'id': '106661028',
#    'premium': False,
#    'name': 'Агроном',
#    'department': None,
#    'has_test': False,
#    'response_letter_required': False,
#    'area': {'id': '1', 'name': 'Москва', 'url': 'https://api.hh.ru/areas/1'},
#    'salary': None,
#    'type': {'id': 'open', 'name': 'Открытая'},
#    'address': None,
#    'response_url': None,
#    'sort_point_distance': None,
#    'published_at': '2024-09-02T15:40:14+0300',
#    'created_at': '2024-09-02T15:40:14+0300',
#    'archived': False,
#    'apply_alternate_url': 'https://hh.ru/applicant/vacancy_response?vacancyId=106661028',
#    'show_logo_in_search': None,
#    'insider_interview': None,
#    'url': 'https://api.hh.ru/vacancies/106661028?host=hh.ru',
#    'alternate_url': 'https://hh.ru/vacancy/106661028',
#    'relations': [],
#    'employer': {'id': '1124',
#     'name': 'Fersol',
#     'url': 'https://api.hh.ru/employers/1124',
#     'alternate_url': 'https://hh.ru/employer/1124',
#     'logo_urls': {'original': 'https://img.hhcdn.ru/employer-logo-original/1002135.jpg',
#      '90': 'https://img.hhcdn.ru/employer-logo/5629320.jpeg',
#      '240': 'https://img.hhcdn.ru/employer-logo/5629321.jpeg'},
#     'vacancies_url': 'https://api.hh.ru/vacancies?employer_id=1124',
#     'accredited_it_employer': False,
#     'trusted': True},
#    'snippet': {'requirement': 'Высшее образование по направлению Агрономия. Знание и понимание технологий возделывания основных с\\х культур. Знание и понимание биологии развития растений...',
#     'responsibility': 'Проведение сопоставлений полимерных решений для систем формирования условий выращивания культуры. Анализ и выбор свойств решения для определённой культуры. '},
#    'contacts': None,
#    'schedule': {'id': 'fullDay', 'name': 'Полный день'},
#    'working_days': [],
#    'working_time_intervals': [],
#    'working_time_modes': [],
#    'accept_temporary': False,
#    'professional_roles': [{'id': '7', 'name': 'Агроном'}],
#    'accept_incomplete_resumes': False,
#    'experience': {'id': 'moreThan6', 'name': 'Более 6 лет'},
#    'employment': {'id': 'full', 'name': 'Полная занятость'},
#    'adv_response_url': None,
#    'is_adv_vacancy': False,
#    'adv_context': None},
#   {'id': '102197513',
#    'premium': False,
#    'name': 'Главный агроном',
#    'department': None,
#    'has_test': False,
#    'response_letter_required': False,
#    'area': {'id': '1', 'name': 'Москва', 'url': 'https://api.hh.ru/areas/1'},
#    'salary': None,
#    'type': {'id': 'open', 'name': 'Открытая'},
#    'address': {'city': None,
#     'street': None,
#     'building': None,
#     'lat': 45.03540698031786,
#     'lng': 38.97527692839503,
#     'description': None,
#     'raw': 'г. Краснодар улица Солнечная 15/5',
#     'metro': None,
#     'metro_stations': [],
#     'id': '228786'},
#    'response_url': None,
#    'sort_point_distance': None,
#    'published_at': '2024-09-02T09:26:14+0300',
#    'created_at': '2024-09-02T09:26:14+0300',
#    'archived': False,
#    'apply_alternate_url': 'https://hh.ru/applicant/vacancy_response?vacancyId=102197513',
#    'branding': {'type': 'MAKEUP', 'tariff': None},
#    'show_logo_in_search': True,
#    'insider_interview': None,
#    'url': 'https://api.hh.ru/vacancies/102197513?host=hh.ru',
#    'alternate_url': 'https://hh.ru/vacancy/102197513',
#    'relations': [],
#    'employer': {'id': '49357',
#     'name': 'МАГНИТ, Розничная сеть',
#     'url': 'https://api.hh.ru/employers/49357',
#     'alternate_url': 'https://hh.ru/employer/49357',
#     'logo_urls': {'original': 'https://img.hhcdn.ru/employer-logo-original/1261115.jpg',
#      '90': 'https://img.hhcdn.ru/employer-logo/6664786.jpeg',
#      '240': 'https://img.hhcdn.ru/employer-logo/6664787.jpeg'},
#     'vacancies_url': 'https://api.hh.ru/vacancies?employer_id=49357',
#     'accredited_it_employer': False,
#     'trusted': True},
#    'snippet': {'requirement': 'Высшее образование (<highlighttext>агроном</highlighttext>). Опыт работы в должности Главного агронома, Директора по производству, Операционного директора на производстве в крупных холдингах по...',
#     'responsibility': 'Анализ агротехнических и грибоводческих решений агрономов ЗЛ, МнД и ГрК в ходе управления выращиванием продукции. Выработка регламентов выращивания, защиты, формирование...'},
#    'contacts': None,
#    'schedule': {'id': 'fullDay', 'name': 'Полный день'},
#    'working_days': [],
#    'working_time_intervals': [],
#    'working_time_modes': [],
#    'accept_temporary': False,
#    'professional_roles': [{'id': '7', 'name': 'Агроном'}],
#    'accept_incomplete_resumes': False,
#    'experience': {'id': 'between3And6', 'name': 'От 3 до 6 лет'},
#    'employment': {'id': 'full', 'name': 'Полная занятость'},
#    'adv_response_url': None,
#    'is_adv_vacancy': False,
#    'adv_context': None},
#   {'id': '105990501',
#    'premium': False,
#    'name': 'Агроном-садовник',
#    'department': None,
#    'has_test': False,
#    'response_letter_required': False,
#    'area': {'id': '1', 'name': 'Москва', 'url': 'https://api.hh.ru/areas/1'},
#    'salary': {'from': 100000, 'to': 150000, 'currency': 'RUR', 'gross': False},
#    'type': {'id': 'open', 'name': 'Открытая'},
#    'address': {'city': 'Москва',
#     'street': 'Киевское шоссе 22-й (п Московский) километр',
#     'building': '4стр1',
#     'lat': 55.634151,
#     'lng': 37.441026,
#     'description': None,
#     'raw': 'Москва, Киевское шоссе 22-й (п Московский) километр, 4стр1',
#     'metro': {'station_name': 'Румянцево',
#      'line_name': 'Сокольническая',
#      'station_id': '1.513',
#      'line_id': '1',
#      'lat': 55.633,
#      'lng': 37.4419},
#     'metro_stations': [{'station_name': 'Румянцево',
#       'line_name': 'Сокольническая',
#       'station_id': '1.513',
#       'line_id': '1',
#       'lat': 55.633,
#       'lng': 37.4419}],
#     'id': '5648157'},
#    'response_url': None,
#    'sort_point_distance': None,
#    'published_at': '2024-09-12T12:24:37+0300',
#    'created_at': '2024-09-12T12:24:37+0300',
#    'archived': False,
#    'apply_alternate_url': 'https://hh.ru/applicant/vacancy_response?vacancyId=105990501',
#    'insider_interview': None,
#    'url': 'https://api.hh.ru/vacancies/105990501?host=hh.ru',
#    'alternate_url': 'https://hh.ru/vacancy/105990501',
#    'relations': [],
#    'employer': {'id': '1689259',
#     'name': 'ДЖЕЙКЕТ РАБОТА',
#     'url': 'https://api.hh.ru/employers/1689259',
#     'alternate_url': 'https://hh.ru/employer/1689259',
#     'logo_urls': None,
#     'vacancies_url': 'https://api.hh.ru/vacancies?employer_id=1689259',
#     'accredited_it_employer': False,
#     'trusted': True},
#    'snippet': {'requirement': 'Знание растений Подмосковья и способы ухода за ними. Образование - аграрный колледж или институт. Умение работать садовым инструментом. Аккуратность и трудолюбие. ',
#     'responsibility': 'Самостоятельный уход за растениями. Руководство бригадой рабочих для сервисного обслуживания зеленых насаждений на территории клиентов. Реализация проектов по благоустройству и...'},
#    'contacts': None,
#    'schedule': {'id': 'flexible', 'name': 'Гибкий график'},
#    'working_days': [],
#    'working_time_intervals': [],
#    'working_time_modes': [],
#    'accept_temporary': False,
#    'professional_roles': [{'id': '7', 'name': 'Агроном'}],
#    'accept_incomplete_resumes': True,
#    'experience': {'id': 'between1And3', 'name': 'От 1 года до 3 лет'},
#    'employment': {'id': 'full', 'name': 'Полная занятость'},
#    'adv_response_url': None,
#    'is_adv_vacancy': False,
#    'adv_context': None},
#   {'id': '106238837',
#    'premium': False,
#    'name': 'Главный инженер проекта',
#    'department': None,
#    'has_test': False,
#    'response_letter_required': False,
#    'area': {'id': '1', 'name': 'Москва', 'url': 'https://api.hh.ru/areas/1'},
#    'salary': {'from': None, 'to': 200000, 'currency': 'RUR', 'gross': True},
#    'type': {'id': 'open', 'name': 'Открытая'},
#    'address': {'city': 'Москва',
#     'street': 'улица Радио',
#     'building': '23/9с1',
#     'lat': 55.763017,
#     'lng': 37.683356,
#     'description': None,
#     'raw': 'Москва, улица Радио, 23/9с1',
#     'metro': {'station_name': 'Лефортово',
#      'line_name': 'Большая кольцевая линия',
#      'station_id': '97.825',
#      'line_id': '97',
#      'lat': 55.764444,
#      'lng': 37.702778},
#     'metro_stations': [{'station_name': 'Лефортово',
#       'line_name': 'Большая кольцевая линия',
#       'station_id': '97.825',
#       'line_id': '97',
#       'lat': 55.764444,
#       'lng': 37.702778}],
#     'id': '14958977'},
#    'response_url': None,
#    'sort_point_distance': None,
#    'published_at': '2024-08-23T10:13:05+0300',
#    'created_at': '2024-08-23T10:13:05+0300',
#    'archived': False,
#    'apply_alternate_url': 'https://hh.ru/applicant/vacancy_response?vacancyId=106238837',
#    'show_logo_in_search': None,
#    'insider_interview': None,
#    'url': 'https://api.hh.ru/vacancies/106238837?host=hh.ru',
#    'alternate_url': 'https://hh.ru/vacancy/106238837',
#    'relations': [],
#    'employer': {'id': '10703368',
#     'name': 'Орка Проект',
#     'url': 'https://api.hh.ru/employers/10703368',
#     'alternate_url': 'https://hh.ru/employer/10703368',
#     'logo_urls': {'90': 'https://img.hhcdn.ru/employer-logo/6498641.png',
#      '240': 'https://img.hhcdn.ru/employer-logo/6498642.png',
#      'original': 'https://img.hhcdn.ru/employer-logo-original/1219550.png'},
#     'vacancies_url': 'https://api.hh.ru/vacancies?employer_id=10703368',
#     'accredited_it_employer': False,
#     'trusted': True},
#    'snippet': {'requirement': 'Высшее техническое образование (проектирование, архитектура). Опыт работы не менее 5-ти лет. Опыт работы проектировщиком. Опыт согласования документации с Москомархитектурой...',
#     'responsibility': 'Подготовка технических заданий и заданий на проектирование. Взаимоувязка проектных решений разделов АР, КР и инженерных систем. Организация работы смежных разделов...'},
#    'contacts': None,
#    'schedule': {'id': 'fullDay', 'name': 'Полный день'},
#    'working_days': [],
#    'working_time_intervals': [],
#    'working_time_modes': [],
#    'accept_temporary': False,
#    'professional_roles': [{'id': '30', 'name': 'Главный инженер проекта'}],
#    'accept_incomplete_resumes': False,
#    'experience': {'id': 'moreThan6', 'name': 'Более 6 лет'},
#    'employment': {'id': 'full', 'name': 'Полная занятость'},
#    'adv_response_url': None,
#    'is_adv_vacancy': False,
#    'adv_context': None},
#   {'id': '105721839',
#    'premium': False,
#    'name': 'Агроном',
#    'department': None,
#    'has_test': False,
#    'response_letter_required': False,
#    'area': {'id': '1', 'name': 'Москва', 'url': 'https://api.hh.ru/areas/1'},
#    'salary': {'from': 60000, 'to': 80000, 'currency': 'RUR', 'gross': True},
#    'type': {'id': 'open', 'name': 'Открытая'},
#    'address': {'city': 'Москва',
#     'street': None,
#     'building': 'парк Ходынское поле',
#     'lat': 55.786743,
#     'lng': 37.53031,
#     'description': None,
#     'raw': 'Москва, парк Ходынское поле',
#     'metro': None,
#     'metro_stations': [],
#     'id': '13158341'},
#    'response_url': None,
#    'sort_point_distance': None,
#    'published_at': '2024-09-12T09:06:00+0300',
#    'created_at': '2024-09-12T09:06:00+0300',
#    'archived': False,
#    'apply_alternate_url': 'https://hh.ru/applicant/vacancy_response?vacancyId=105721839',
#    'show_logo_in_search': None,
#    'insider_interview': None,
#    'url': 'https://api.hh.ru/vacancies/105721839?host=hh.ru',
#    'alternate_url': 'https://hh.ru/vacancy/105721839',
#    'relations': [],
#    'employer': {'id': '1617659',
#     'name': 'ГАУК Парк культуры и отдыха Ходынское поле',
#     'url': 'https://api.hh.ru/employers/1617659',
#     'alternate_url': 'https://hh.ru/employer/1617659',
#     'logo_urls': {'240': 'https://img.hhcdn.ru/employer-logo/5501925.jpeg',
#      '90': 'https://img.hhcdn.ru/employer-logo/5501924.jpeg',
#      'original': 'https://img.hhcdn.ru/employer-logo-original/970279.jpeg'},
#     'vacancies_url': 'https://api.hh.ru/vacancies?employer_id=1617659',
#     'accredited_it_employer': False,
#     'trusted': True},
#    'snippet': {'requirement': 'высшее профессиональное образование. Должен знать: Агротехнические особенности декоративных растений. Основы дендрологии, ботаники, почвоведения, декоративного садоводства. Экологические, социально-экономические, агротехнические, технические...',
#     'responsibility': 'Осуществляет эскизные зарисовки, фотографирование объектов проектирования, наиболее характерных пейзажей, памятников истории и культуры. Разрабатывает ландшафтно-планировочные решения по конкретным разделам...'},
#    'contacts': None,
#    'schedule': {'id': 'fullDay', 'name': 'Полный день'},
#    'working_days': [],
#    'working_time_intervals': [],
#    'working_time_modes': [],
#    'accept_temporary': False,
#    'professional_roles': [{'id': '7', 'name': 'Агроном'}],
#    'accept_incomplete_resumes': False,
#    'experience': {'id': 'between3And6', 'name': 'От 3 до 6 лет'},
#    'employment': {'id': 'full', 'name': 'Полная занятость'},
#    'adv_response_url': None,
#    'is_adv_vacancy': False,
#    'adv_context': None}],
#  'pages': 6}

# %%
df = pd.DataFrame.from_records(get_vacancies(vacancy_name='Агроном').get('items'))
df
# Out:
#           id  premium                                               name  \
# 0  107214681    False                                    Главный агроном
# 1  106335339    False  Управляющий агрофермой (Агроном) релокация на ...
# 2  106435824    False    Ландшафтный дизайнер/Садовник/Дендролог/Агроном
# 3  106918725    False                                            Агроном
# 4  105672373    False                                   Агроном/овощевод
# 5  107065128    False  Специалист по уходу за офисными растениями (са...
# 6  106702001    False                          Агроном (Растениеводство)
# 7  106066250    False  Биолог/специалист по уходу за горшечными расте...
# 8  106107473    False                                            Агроном
# 9  106267536    False                                            Агроном
#
#   department  has_test  response_letter_required  \
# 0       None     False                     False
# 1       None     False                      True
# 2       None     False                     False
# 3       None     False                     False
# 4       None     False                     False
# 5       None     False                     False
# 6       None     False                     False
# 7       None     False                     False
# 8       None     False                     False
# 9       None     False                     False
#
#                                                 area  \
# 0  {'id': '1', 'name': 'Москва', 'url': 'https://...
# 1  {'id': '1', 'name': 'Москва', 'url': 'https://...
# 2  {'id': '1', 'name': 'Москва', 'url': 'https://...
# 3  {'id': '1', 'name': 'Москва', 'url': 'https://...
# 4  {'id': '1', 'name': 'Москва', 'url': 'https://...
# 5  {'id': '1', 'name': 'Москва', 'url': 'https://...
# 6  {'id': '1', 'name': 'Москва', 'url': 'https://...
# 7  {'id': '1', 'name': 'Москва', 'url': 'https://...
# 8  {'id': '1', 'name': 'Москва', 'url': 'https://...
# 9  {'id': '1', 'name': 'Москва', 'url': 'https://...
#
#                                               salary  \
# 0  {'from': 180000, 'to': None, 'currency': 'RUR'...
# 1  {'from': 2000, 'to': None, 'currency': 'USD', ...
# 2  {'from': 180000, 'to': None, 'currency': 'RUR'...
# 3  {'from': 30000, 'to': 40000, 'currency': 'RUR'...
# 4  {'from': 120000, 'to': None, 'currency': 'RUR'...
# 5  {'from': 25000, 'to': 100000, 'currency': 'RUR...
# 6  {'from': 130000, 'to': 150000, 'currency': 'RU...
# 7  {'from': 35000, 'to': 68000, 'currency': 'RUR'...
# 8  {'from': 50000, 'to': 100000, 'currency': 'RUR...
# 9  {'from': 80000, 'to': None, 'currency': 'RUR',...
#
#                                  type  \
# 0  {'id': 'open', 'name': 'Открытая'}
# 1  {'id': 'open', 'name': 'Открытая'}
# 2  {'id': 'open', 'name': 'Открытая'}
# 3  {'id': 'open', 'name': 'Открытая'}
# 4  {'id': 'open', 'name': 'Открытая'}
# 5  {'id': 'open', 'name': 'Открытая'}
# 6  {'id': 'open', 'name': 'Открытая'}
# 7  {'id': 'open', 'name': 'Открытая'}
# 8  {'id': 'open', 'name': 'Открытая'}
# 9  {'id': 'open', 'name': 'Открытая'}
#
#                                              address response_url  \
# 0                                               None         None
# 1                                               None         None
# 2                                               None         None
# 3  {'city': 'Москва', 'street': 'улица Плеханова'...         None
# 4                                               None         None
# 5  {'city': 'Москва', 'street': 'Пресненская набе...         None
# 6  {'city': 'деревня Кончинка', 'street': None, '...         None
# 7  {'city': 'деревня Аносино', 'street': 'Универс...         None
# 8                                               None         None
# 9                                               None         None
#
#   sort_point_distance              published_at                created_at  \
# 0                None  2024-09-12T17:36:02+0300  2024-09-12T17:36:02+0300
# 1                None  2024-08-26T14:39:27+0300  2024-08-26T14:39:27+0300
# 2                None  2024-09-02T10:32:17+0300  2024-09-02T10:32:17+0300
# 3                None  2024-09-06T16:36:22+0300  2024-09-06T16:36:22+0300
# 4                None  2024-08-28T12:27:02+0300  2024-08-28T12:27:02+0300
# 5                None  2024-09-10T15:15:41+0300  2024-09-10T15:15:41+0300
# 6                None  2024-09-12T11:55:28+0300  2024-09-12T11:55:28+0300
# 7                None  2024-08-20T14:14:14+0300  2024-08-20T14:14:14+0300
# 8                None  2024-08-21T11:17:36+0300  2024-08-21T11:17:36+0300
# 9                None  2024-09-10T15:49:41+0300  2024-09-10T15:49:41+0300
#
#    archived                                apply_alternate_url  \
# 0     False  https://hh.ru/applicant/vacancy_response?vacan...
# 1     False  https://hh.ru/applicant/vacancy_response?vacan...
# 2     False  https://hh.ru/applicant/vacancy_response?vacan...
# 3     False  https://hh.ru/applicant/vacancy_response?vacan...
# 4     False  https://hh.ru/applicant/vacancy_response?vacan...
# 5     False  https://hh.ru/applicant/vacancy_response?vacan...
# 6     False  https://hh.ru/applicant/vacancy_response?vacan...
# 7     False  https://hh.ru/applicant/vacancy_response?vacan...
# 8     False  https://hh.ru/applicant/vacancy_response?vacan...
# 9     False  https://hh.ru/applicant/vacancy_response?vacan...
#
#    show_logo_in_search insider_interview  \
# 0                  NaN              None
# 1                  NaN              None
# 2                  NaN              None
# 3                  NaN              None
# 4                  NaN              None
# 5                  NaN              None
# 6                  NaN              None
# 7                  NaN              None
# 8                  NaN              None
# 9                  NaN              None
#
#                                                 url  \
# 0  https://api.hh.ru/vacancies/107214681?host=hh.ru
# 1  https://api.hh.ru/vacancies/106335339?host=hh.ru
# 2  https://api.hh.ru/vacancies/106435824?host=hh.ru
# 3  https://api.hh.ru/vacancies/106918725?host=hh.ru
# 4  https://api.hh.ru/vacancies/105672373?host=hh.ru
# 5  https://api.hh.ru/vacancies/107065128?host=hh.ru
# 6  https://api.hh.ru/vacancies/106702001?host=hh.ru
# 7  https://api.hh.ru/vacancies/106066250?host=hh.ru
# 8  https://api.hh.ru/vacancies/106107473?host=hh.ru
# 9  https://api.hh.ru/vacancies/106267536?host=hh.ru
#
#                      alternate_url relations  \
# 0  https://hh.ru/vacancy/107214681        []
# 1  https://hh.ru/vacancy/106335339        []
# 2  https://hh.ru/vacancy/106435824        []
# 3  https://hh.ru/vacancy/106918725        []
# 4  https://hh.ru/vacancy/105672373        []
# 5  https://hh.ru/vacancy/107065128        []
# 6  https://hh.ru/vacancy/106702001        []
# 7  https://hh.ru/vacancy/106066250        []
# 8  https://hh.ru/vacancy/106107473        []
# 9  https://hh.ru/vacancy/106267536        []
#
#                                             employer  \
# 0  {'id': '1069209', 'name': 'Кадровый центр През...
# 1  {'id': '11217206', 'name': 'Всё, я увольняюсь!...
# 2  {'id': '56479', 'name': 'Дэстэн Партнерс', 'ur...
# 3  {'id': '11412752', 'name': 'Здоровый Сад', 'ur...
# 4  {'id': '2161246', 'name': 'МОСМАКС ТРЕТЬЯКОВСК...
# 5  {'id': '3926338', 'name': 'Дизайн Инжиниринг',...
# 6  {'id': '161720', 'name': 'КОРНИ, Питомник раст...
# 7  {'id': '787380', 'name': 'Бюро Фитодизайна Фик...
# 8  {'id': '10797718', 'name': 'Райдер СНГ', 'url'...
# 9  {'id': '1197490', 'name': 'Озеленитель Стройгр...
#
#                                              snippet contacts  \
# 0  {'requirement': 'Высшее профильное образование...     None
# 1  {'requirement': 'Профильное образование. Релев...     None
# 2  {'requirement': 'Опыт работы в смежной должнос...     None
# 3  {'requirement': 'Ответственность. Кропотливост...     None
# 4  {'requirement': 'Честность, добросовестность, ...     None
# 5  {'requirement': 'Диплом об профильном образова...     None
# 6  {'requirement': 'Опыт работы в питомнике, садо...     None
# 7  {'requirement': 'Организованность. Высокая отв...     None
# 8  {'requirement': 'Tребовaния к вaм:  Bысшee или...     None
# 9  {'requirement': 'Образование не ниже среднего ...     None
#
#                                       schedule working_days  \
# 0     {'id': 'fullDay', 'name': 'Полный день'}           []
# 1     {'id': 'fullDay', 'name': 'Полный день'}           []
# 2     {'id': 'fullDay', 'name': 'Полный день'}           []
# 3     {'id': 'fullDay', 'name': 'Полный день'}           []
# 4     {'id': 'fullDay', 'name': 'Полный день'}           []
# 5  {'id': 'flexible', 'name': 'Гибкий график'}           []
# 6     {'id': 'fullDay', 'name': 'Полный день'}           []
# 7     {'id': 'fullDay', 'name': 'Полный день'}           []
# 8     {'id': 'fullDay', 'name': 'Полный день'}           []
# 9     {'id': 'fullDay', 'name': 'Полный день'}           []
#
#                               working_time_intervals working_time_modes  \
# 0                                                 []                 []
# 1                                                 []                 []
# 2                                                 []                 []
# 3                                                 []                 []
# 4                                                 []                 []
# 5  [{'id': 'from_four_to_six_hours_in_a_day', 'na...                 []
# 6                                                 []                 []
# 7                                                 []                 []
# 8                                                 []                 []
# 9                                                 []                 []
#
#    accept_temporary                            professional_roles  \
# 0             False              [{'id': '7', 'name': 'Агроном'}]
# 1             False              [{'id': '7', 'name': 'Агроном'}]
# 2             False  [{'id': '34', 'name': 'Дизайнер, художник'}]
# 3              True              [{'id': '7', 'name': 'Агроном'}]
# 4             False              [{'id': '7', 'name': 'Агроном'}]
# 5              True              [{'id': '7', 'name': 'Агроном'}]
# 6              True              [{'id': '7', 'name': 'Агроном'}]
# 7             False              [{'id': '40', 'name': 'Другое'}]
# 8             False              [{'id': '7', 'name': 'Агроном'}]
# 9             False              [{'id': '7', 'name': 'Агроном'}]
#
#    accept_incomplete_resumes  \
# 0                      False
# 1                      False
# 2                      False
# 3                      False
# 4                       True
# 5                      False
# 6                       True
# 7                       True
# 8                      False
# 9                      False
#
#                                           experience  \
# 0    {'id': 'between3And6', 'name': 'От 3 до 6 лет'}
# 1    {'id': 'between3And6', 'name': 'От 3 до 6 лет'}
# 2  {'id': 'between1And3', 'name': 'От 1 года до 3...
# 3  {'id': 'between1And3', 'name': 'От 1 года до 3...
# 4  {'id': 'between1And3', 'name': 'От 1 года до 3...
# 5  {'id': 'between1And3', 'name': 'От 1 года до 3...
# 6    {'id': 'between3And6', 'name': 'От 3 до 6 лет'}
# 7  {'id': 'between1And3', 'name': 'От 1 года до 3...
# 8        {'id': 'noExperience', 'name': 'Нет опыта'}
# 9        {'id': 'noExperience', 'name': 'Нет опыта'}
#
#                                       employment adv_response_url  \
# 0     {'id': 'full', 'name': 'Полная занятость'}             None
# 1     {'id': 'full', 'name': 'Полная занятость'}             None
# 2     {'id': 'full', 'name': 'Полная занятость'}             None
# 3  {'id': 'part', 'name': 'Частичная занятость'}             None
# 4     {'id': 'full', 'name': 'Полная занятость'}             None
# 5  {'id': 'part', 'name': 'Частичная занятость'}             None
# 6     {'id': 'full', 'name': 'Полная занятость'}             None
# 7     {'id': 'full', 'name': 'Полная занятость'}             None
# 8     {'id': 'full', 'name': 'Полная занятость'}             None
# 9     {'id': 'full', 'name': 'Полная занятость'}             None
#
#    is_adv_vacancy adv_context
# 0           False        None
# 1           False        None
# 2           False        None
# 3           False        None
# 4           False        None
# 5           False        None
# 6           False        None
# 7           False        None
# 8           False        None
# 9           False        None

# %%
df1 = df.copy()

# %%
df1['area'] = df1.area.apply(lambda x: x.get('name'))
df1['salary_from'] = df1.salary.apply(lambda x: x.get('from', None) if x else None)
df1['salary_to'] = df1.salary.apply(lambda x: x.get('to', None) if x else None)
df1['salary_currency'] = df1.salary.apply(lambda x: x.get('currency', None) if x else None)
df1['salary_gross'] = df1.salary.apply(lambda x: x.get('gross', None) if x else None)
df1.drop(columns=['salary'], inplace=True)
df1.type	= df1.type.apply(lambda x: x.get('name', None) if x else None)
df1['city_address'] = df1.address.apply(lambda x: x.get('city', None) if x else None)
df1['street_adress'] = df1.address.apply(lambda x: x.get('street', None) if x else None)
df1['metro_station'] = df1.address.apply(lambda x: x.get('metro_station', None)
df1['metro_line'] = df1.address.apply(lambda x: x.get('metro_line', None)
df1['metro_distance'] = df1.address.apply(lambda x: x.get('metro_distance', None)
df1['r']
#df1.drop(columns=['address'], inplace=True)

# %%
df1
# Out:
#           id  premium                                               name  \
# 0  107214681    False                                    Главный агроном
# 1  106335339    False  Управляющий агрофермой (Агроном) релокация на ...
# 2  106435824    False    Ландшафтный дизайнер/Садовник/Дендролог/Агроном
# 3  106918725    False                                            Агроном
# 4  105672373    False                                   Агроном/овощевод
# 5  107065128    False  Специалист по уходу за офисными растениями (са...
# 6  106702001    False                          Агроном (Растениеводство)
# 7  106066250    False  Биолог/специалист по уходу за горшечными расте...
# 8  106107473    False                                            Агроном
# 9  106267536    False                                            Агроном
#
#   department  has_test  response_letter_required    area      type  \
# 0       None     False                     False  Москва  Открытая
# 1       None     False                      True  Москва  Открытая
# 2       None     False                     False  Москва  Открытая
# 3       None     False                     False  Москва  Открытая
# 4       None     False                     False  Москва  Открытая
# 5       None     False                     False  Москва  Открытая
# 6       None     False                     False  Москва  Открытая
# 7       None     False                     False  Москва  Открытая
# 8       None     False                     False  Москва  Открытая
# 9       None     False                     False  Москва  Открытая
#
#   response_url sort_point_distance              published_at  \
# 0         None                None  2024-09-12T17:36:02+0300
# 1         None                None  2024-08-26T14:39:27+0300
# 2         None                None  2024-09-02T10:32:17+0300
# 3         None                None  2024-09-06T16:36:22+0300
# 4         None                None  2024-08-28T12:27:02+0300
# 5         None                None  2024-09-10T15:15:41+0300
# 6         None                None  2024-09-12T11:55:28+0300
# 7         None                None  2024-08-20T14:14:14+0300
# 8         None                None  2024-08-21T11:17:36+0300
# 9         None                None  2024-09-10T15:49:41+0300
#
#                  created_at  archived  \
# 0  2024-09-12T17:36:02+0300     False
# 1  2024-08-26T14:39:27+0300     False
# 2  2024-09-02T10:32:17+0300     False
# 3  2024-09-06T16:36:22+0300     False
# 4  2024-08-28T12:27:02+0300     False
# 5  2024-09-10T15:15:41+0300     False
# 6  2024-09-12T11:55:28+0300     False
# 7  2024-08-20T14:14:14+0300     False
# 8  2024-08-21T11:17:36+0300     False
# 9  2024-09-10T15:49:41+0300     False
#
#                                  apply_alternate_url  show_logo_in_search  \
# 0  https://hh.ru/applicant/vacancy_response?vacan...                  NaN
# 1  https://hh.ru/applicant/vacancy_response?vacan...                  NaN
# 2  https://hh.ru/applicant/vacancy_response?vacan...                  NaN
# 3  https://hh.ru/applicant/vacancy_response?vacan...                  NaN
# 4  https://hh.ru/applicant/vacancy_response?vacan...                  NaN
# 5  https://hh.ru/applicant/vacancy_response?vacan...                  NaN
# 6  https://hh.ru/applicant/vacancy_response?vacan...                  NaN
# 7  https://hh.ru/applicant/vacancy_response?vacan...                  NaN
# 8  https://hh.ru/applicant/vacancy_response?vacan...                  NaN
# 9  https://hh.ru/applicant/vacancy_response?vacan...                  NaN
#
#   insider_interview                                               url  \
# 0              None  https://api.hh.ru/vacancies/107214681?host=hh.ru
# 1              None  https://api.hh.ru/vacancies/106335339?host=hh.ru
# 2              None  https://api.hh.ru/vacancies/106435824?host=hh.ru
# 3              None  https://api.hh.ru/vacancies/106918725?host=hh.ru
# 4              None  https://api.hh.ru/vacancies/105672373?host=hh.ru
# 5              None  https://api.hh.ru/vacancies/107065128?host=hh.ru
# 6              None  https://api.hh.ru/vacancies/106702001?host=hh.ru
# 7              None  https://api.hh.ru/vacancies/106066250?host=hh.ru
# 8              None  https://api.hh.ru/vacancies/106107473?host=hh.ru
# 9              None  https://api.hh.ru/vacancies/106267536?host=hh.ru
#
#                      alternate_url relations  \
# 0  https://hh.ru/vacancy/107214681        []
# 1  https://hh.ru/vacancy/106335339        []
# 2  https://hh.ru/vacancy/106435824        []
# 3  https://hh.ru/vacancy/106918725        []
# 4  https://hh.ru/vacancy/105672373        []
# 5  https://hh.ru/vacancy/107065128        []
# 6  https://hh.ru/vacancy/106702001        []
# 7  https://hh.ru/vacancy/106066250        []
# 8  https://hh.ru/vacancy/106107473        []
# 9  https://hh.ru/vacancy/106267536        []
#
#                                             employer  \
# 0  {'id': '1069209', 'name': 'Кадровый центр През...
# 1  {'id': '11217206', 'name': 'Всё, я увольняюсь!...
# 2  {'id': '56479', 'name': 'Дэстэн Партнерс', 'ur...
# 3  {'id': '11412752', 'name': 'Здоровый Сад', 'ur...
# 4  {'id': '2161246', 'name': 'МОСМАКС ТРЕТЬЯКОВСК...
# 5  {'id': '3926338', 'name': 'Дизайн Инжиниринг',...
# 6  {'id': '161720', 'name': 'КОРНИ, Питомник раст...
# 7  {'id': '787380', 'name': 'Бюро Фитодизайна Фик...
# 8  {'id': '10797718', 'name': 'Райдер СНГ', 'url'...
# 9  {'id': '1197490', 'name': 'Озеленитель Стройгр...
#
#                                              snippet contacts  \
# 0  {'requirement': 'Высшее профильное образование...     None
# 1  {'requirement': 'Профильное образование. Релев...     None
# 2  {'requirement': 'Опыт работы в смежной должнос...     None
# 3  {'requirement': 'Ответственность. Кропотливост...     None
# 4  {'requirement': 'Честность, добросовестность, ...     None
# 5  {'requirement': 'Диплом об профильном образова...     None
# 6  {'requirement': 'Опыт работы в питомнике, садо...     None
# 7  {'requirement': 'Организованность. Высокая отв...     None
# 8  {'requirement': 'Tребовaния к вaм:  Bысшee или...     None
# 9  {'requirement': 'Образование не ниже среднего ...     None
#
#                                       schedule working_days  \
# 0     {'id': 'fullDay', 'name': 'Полный день'}           []
# 1     {'id': 'fullDay', 'name': 'Полный день'}           []
# 2     {'id': 'fullDay', 'name': 'Полный день'}           []
# 3     {'id': 'fullDay', 'name': 'Полный день'}           []
# 4     {'id': 'fullDay', 'name': 'Полный день'}           []
# 5  {'id': 'flexible', 'name': 'Гибкий график'}           []
# 6     {'id': 'fullDay', 'name': 'Полный день'}           []
# 7     {'id': 'fullDay', 'name': 'Полный день'}           []
# 8     {'id': 'fullDay', 'name': 'Полный день'}           []
# 9     {'id': 'fullDay', 'name': 'Полный день'}           []
#
#                               working_time_intervals working_time_modes  \
# 0                                                 []                 []
# 1                                                 []                 []
# 2                                                 []                 []
# 3                                                 []                 []
# 4                                                 []                 []
# 5  [{'id': 'from_four_to_six_hours_in_a_day', 'na...                 []
# 6                                                 []                 []
# 7                                                 []                 []
# 8                                                 []                 []
# 9                                                 []                 []
#
#    accept_temporary                            professional_roles  \
# 0             False              [{'id': '7', 'name': 'Агроном'}]
# 1             False              [{'id': '7', 'name': 'Агроном'}]
# 2             False  [{'id': '34', 'name': 'Дизайнер, художник'}]
# 3              True              [{'id': '7', 'name': 'Агроном'}]
# 4             False              [{'id': '7', 'name': 'Агроном'}]
# 5              True              [{'id': '7', 'name': 'Агроном'}]
# 6              True              [{'id': '7', 'name': 'Агроном'}]
# 7             False              [{'id': '40', 'name': 'Другое'}]
# 8             False              [{'id': '7', 'name': 'Агроном'}]
# 9             False              [{'id': '7', 'name': 'Агроном'}]
#
#    accept_incomplete_resumes  \
# 0                      False
# 1                      False
# 2                      False
# 3                      False
# 4                       True
# 5                      False
# 6                       True
# 7                       True
# 8                      False
# 9                      False
#
#                                           experience  \
# 0    {'id': 'between3And6', 'name': 'От 3 до 6 лет'}
# 1    {'id': 'between3And6', 'name': 'От 3 до 6 лет'}
# 2  {'id': 'between1And3', 'name': 'От 1 года до 3...
# 3  {'id': 'between1And3', 'name': 'От 1 года до 3...
# 4  {'id': 'between1And3', 'name': 'От 1 года до 3...
# 5  {'id': 'between1And3', 'name': 'От 1 года до 3...
# 6    {'id': 'between3And6', 'name': 'От 3 до 6 лет'}
# 7  {'id': 'between1And3', 'name': 'От 1 года до 3...
# 8        {'id': 'noExperience', 'name': 'Нет опыта'}
# 9        {'id': 'noExperience', 'name': 'Нет опыта'}
#
#                                       employment adv_response_url  \
# 0     {'id': 'full', 'name': 'Полная занятость'}             None
# 1     {'id': 'full', 'name': 'Полная занятость'}             None
# 2     {'id': 'full', 'name': 'Полная занятость'}             None
# 3  {'id': 'part', 'name': 'Частичная занятость'}             None
# 4     {'id': 'full', 'name': 'Полная занятость'}             None
# 5  {'id': 'part', 'name': 'Частичная занятость'}             None
# 6     {'id': 'full', 'name': 'Полная занятость'}             None
# 7     {'id': 'full', 'name': 'Полная занятость'}             None
# 8     {'id': 'full', 'name': 'Полная занятость'}             None
# 9     {'id': 'full', 'name': 'Полная занятость'}             None
#
#    is_adv_vacancy adv_context  salary_from  salary_to salary_currency  \
# 0           False        None       180000        NaN             RUR
# 1           False        None         2000        NaN             USD
# 2           False        None       180000        NaN             RUR
# 3           False        None        30000    40000.0             RUR
# 4           False        None       120000        NaN             RUR
# 5           False        None        25000   100000.0             RUR
# 6           False        None       130000   150000.0             RUR
# 7           False        None        35000    68000.0             RUR
# 8           False        None        50000   100000.0             RUR
# 9           False        None        80000        NaN             RUR
#
#    salary_gross      city_address           street_adress
# 0         False              None                    None
# 1          True              None                    None
# 2         False              None                    None
# 3         False            Москва         улица Плеханова
# 4         False              None                    None
# 5         False            Москва  Пресненская набережная
# 6         False  деревня Кончинка                    None
# 7         False   деревня Аносино   Университетская улица
# 8         False              None                    None
# 9         False              None                    None

# %% [markdown]
# Если Ваш запрос прошел успешно, то вы получите следующие ключи (значения данных ключей вы найдете по ссылке на документацию):

# %%
data.keys()
# Out:
# dict_keys(['items', 'found', 'pages', 'page', 'per_page', 'clusters', 'arguments', 'fixes', 'suggests', 'alternate_url'])

# %% [markdown]
# Выберете для нас 5 наиболее интересных специальностей и получите по ним имеющиеся вакансии:

# %% [markdown]
# Посчитайте сколько всего найдено вакансий:

# %% [markdown]
# Создайте структуру данных, которая будет хранить в себе имя компании и ее координаты (широта и долгота):

# %% [markdown]
# Создайте экземпляр этой структуры данных для каждой компании, которая выставила вакансию:

# %% [markdown]
# Найдите количество вакансий, у которых заданы координаты (значения данных может быть пустым):

# %% [markdown]
# Отберите вакансии, которые расположены в пределах МКАД (можно грубо):

# %% [markdown]
# Постройте график в координатах "широта-долгота" для отображения вакансий внутри МКАД (не забывайте прописать прозрачность, чтобы увидеть скопления):

# %% [markdown]
# **Сделайте выводы о проделанной работе:**

# %% [markdown]
# Вам предстоит проанализировать датасет, содержащий информацию об бриллианта, их стоимости и остальных характеристиках.

# %% [markdown]
# Поясним значения хранящиеся в колонках:
# *   `cut` - огранка бриллианта (относится к одной из примерно 10 наиболее распространенных)
# *   `color` - цвет бриллианта, прозрачные бриллианты имеют градацию `D-Z`, "более высокие" буквы - более желтоватые, но часто имеют лучшие значения, поскольку цвет трудно определить один раз в кольце
# *   `clarity` - чистота бриллианта, наличие включений (внутренних дефектов), чем меньше и мельче, тем лучше
# *   `carat_weight` - масса бриллианта (слабо связана с размером бриллианта, т.к. огранка и качество огранки, как правило, играют большую роль)
# *   `cut_quality` - качество ограники по системе оценки GIA Cut
# *   `lab` - лаборатория оценивания
# *   `meas_length` - длина бриллианта
# *   `meas_width` - ширина бриллианта
# *   `meas_depth` - глубина бриллианта
# *   `total_sales_price` - цена бриллианта в долларах.
# *    **и прочие колонки**

# %% [markdown]
# Скачаем данные:

# %%
# !gdown 10OJ30qlkE-7zK4JuVTDMY3U4nRB4tu_8
# если работайте в jupyter то скачайте датасет с https://drive.google.com/uc?id=10OJ30qlkE-7zK4JuVTDMY3U4nRB4tu_8

# %% [markdown]
# Создадим DataFrame:

# %%
import pandas as pd

diamonds = pd.read_csv("diamonds.csv")

# %% [markdown]
# Выведете первые 5 строк датасета:

# %% [markdown]
# Найдите количество бриллиантов всего в данном датасете:

# %% [markdown]
# Выведите максимальную и минимальную цену бриллианта в формате `номер - цена`:

# %% [markdown]
# Посчитайте количество пропусков (пропуском считается значение `unknown` или `None`):

# %% [markdown]
# Найдите в каких столбцах присутствуют пропуски:

# %% [markdown]
# В нашем датасете присутствуют колонки, которые начинаются с `fancy_color_` или `fluor_`. Большинство значений в этих колонках - `unknown` или `None`, поэтому мы считаем их малоинформативными.

# %% [markdown]
# Ваша задача:

# %% [markdown]
# найти количество таких колонок, которые начинаются с `fancy_color_` или `fluor_`:

# %% [markdown]
# найти количество информативных (не `None` или `unknown`) значений в этих колонках:

# %% [markdown]
# удалить данные колонки из датасета, сохранив изменения (в дальнейшем работаем измененным датасетом):

# %% [markdown]
# Проделайте тоже самое для колонок, начинающихся с `culet_`:

# %% [markdown]
# Посчитайте сколько бы стоил (в тысячах долларов) сейф, в котором хранились бы все бриллианты из датасета:

# %% [markdown]
# Немного необоснованных манипуляций.

# %% [markdown]
# Выберите из датасета строки с четными индексами и выведете значения (не меняя нумерацию индексов):

# %% [markdown]
# А теперь с индексами, кратными 6:

# %% [markdown]
# Выберете из датасета только категорильные признаки и выведете датасет:

# %% [markdown]
# ### Построение графиков

# %% [markdown]
# **Требования к графику:**
#
# 1.   График должен быть подписан
# 2.   Оси должны быть подписаны
# 3.   Должна быть легенда графика
# 4.   График должен быть информативным (желательно без сильных выбросов)
#
# **Все надписи на русском языке!**

# %% [markdown]
# >**Примечание**
# >
# >График необходимо строить для очищенных данных - в них не должно быть пропусков по осям, по которым строите график. При этом **не перезатирайте** имеющийся датафрейм!

# %% [markdown]
# Постройте график `цвет бриллианта - стоимость`:

# %% [markdown]
# Постройте график `лабараторная оценка - кол-во бриллиантов`:

# %% [markdown]
# Постройте график `вес бриллианта - стоимость`:

# %% [markdown]
# Постройте график `система оценки GIA Cut - кол-во бриллиантов`:

# %% [markdown]
# Сделайте выводы по построенным графикам
